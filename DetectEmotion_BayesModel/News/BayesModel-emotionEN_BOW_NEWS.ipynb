# %%
import numpy as np 
import pandas as pd 
pd.set_option('display.max_colwidth', -1)
import os
from time import time
from pprint import pprint
import collections

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.set(font_scale=1.3)

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import classification_report

from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.externals import joblib

import warnings
warnings.filterwarnings('ignore')

np.random.seed(37)

# %%
df_model = pd.read_pickle('../../data/final/NotIot_clean_FR_news_lexic.p')
df_model
# Out:
#      count_words  count_capital_words  count_excl_quest_marks  sentiment  \
# 0    12           0                    0                       joie
# 1    11           0                    0                       tristesse
# 2    5            1                    0                       joie
# 3    7            0                    0                       joie
# 4    15           0                    0                       peur
# 5    7            0                    0                       tristesse
# 6    12           0                    0                       surprise
# 7    11           0                    0                       tristesse
# 8    14           0                    0                       surprise
# 9    7            0                    0                       tristesse
# 10   14           0                    0                       surprise
# 11   11           0                    0                       surprise
# 12   7            0                    0                       surprise
# 13   8            0                    0                       joie
# 14   8            1                    0                       surprise
# 15   11           0                    0                       joie
# 16   8            0                    0                       surprise
# 17   11           0                    0                       joie
# 18   7            0                    0                       tristesse
# 19   10           0                    0                       surprise
# 20   6            0                    0                       surprise
# 21   9            0                    0                       surprise
# 22   9            0                    0                       colère
# 23   10           1                    0                       dégoûter
# 24   7            0                    0                       joie
# 25   7            1                    0                       surprise
# 26   12           0                    0                       joie
# 27   11           0                    0                       surprise
# 28   7            0                    0                       dégoûter
# 29   10           0                    0                       surprise
# ..   ..          ..                   ..                            ...
# 956  10           0                    0                       surprise
# 957  9            0                    0                       joie
# 958  8            0                    0                       dégoûter
# 959  10           0                    0                       joie
# 960  8            0                    0                       joie
# 961  8            0                    0                       joie
# 962  11           0                    0                       tristesse
# 963  9            0                    1                       surprise
# 964  6            0                    0                       tristesse
# 965  9            0                    0                       surprise
# 966  9            0                    0                       surprise
# 967  11           1                    0                       colère
# 968  9            0                    0                       dégoûter
# 969  6            1                    0                       joie
# 970  14           1                    0                       surprise
# 971  6            0                    0                       tristesse
# 972  10           0                    0                       tristesse
# 973  7            0                    0                       joie
# 974  5            0                    0                       joie
# 975  8            0                    0                       tristesse
# 976  10           0                    0                       colère
# 977  9            0                    0                       tristesse
# 978  8            0                    0                       tristesse
# 979  9            0                    0                       joie
# 980  6            0                    0                       surprise
# 981  7            1                    0                       tristesse
# 982  6            0                    0                       tristesse
# 983  11           0                    0                       surprise
# 984  6            0                    0                       surprise
# 985  6            1                    0                       joie
#
#                                                                                  origin_text  \
# 0    Un test pour prédire la rechute du cancer du sein est approuvé
# 1    Un allié de Saddam Hussein est pendu, selon un responsable irakien
# 2    Vues et sons du CES
# 3    Schuey voit Ferrari dévoiler une nouvelle voiture
# 4    Les clôtures et les annulations sont les meilleurs conseils en cas d’épidémie de grippe
# 5    Camions avalés dans l'effondrement du métro
# 6    Une lettre de Sarkozy surprend l'audience sur les dessins animés français
# 7    Construire un monument à un fils, un enfant à la fois
# 8    Un législateur veut interdire les iPod dans les passages pour piétons à New York
# 9    Diabetic attend des lunettes pendant des mois
# 10   Le Soudan demande à l'envoyé des Nations Unies de partir dans 72 heures
# 11   5000 ans après, mais un couple est toujours dans les bras
# 12   La Défense conteste la crédibilité de Russert
# 13   Ozzy, un héros pour les masses hard rock
# 14   Résumé des essais de fuite de la CIA
# 15   Le film de danse prend le dessus sur le numéro 1
# 16   Les nations asiatiques demandent la réforme du Myanmar
# 17   Après le voyage en Irak, Clinton propose des limites de guerre
# 18   7 morts dans un immeuble en feu
# 19   La sueur masculine augmente les niveaux d'hormones des femmes
# 20   Les signaux mitigés de Carphone Warehouse
# 21   Les démocrates complotent de censurer les troupes de Bush
# 22   Cisco poursuit Apple contre le nom de l'iPhone
# 23   La star de BB Jackson nie les commentaires de Goody
# 24   Inter Milan set Serie A win record
# 25   US Airways augmente son offre pour Delta
# 26   La presse voit de l'espoir dans les négociations à la Mecque
# 27   Le fan des Bears perd son pari et change de nom
# 28   Buste d'anneau pornographique national majeur international
# 29   Indice 'cheveux humains' dans la chasse pour avion de ligne
# ..                                                           ...
# 956  Appel frénétique au 911 dans l'affaire Ryan O'Neal
# 957  Le succès de Durant l'emporte sur les Gators
# 958  Un scientifique fouine dans le journal des astronautes
# 959  Les fondateurs de YouTube ont partagé 650 millions de dollars
# 960  Une nation africaine espère que Whoopi pourra aider
# 961  United s'accrocher à six points d'avance
# 962  Un avocat s'empare de la maison de Smith aux Bahamas
# 963  Le super show de Prince était-il trop révélateur?
# 964  Clijsters cherche un long au revoir
# 965  La neige est trop profonde même pour les motoneiges
# 966  Étude: Les phoques sont difficiles au sujet des partenaires
# 967  ROUNDUP: Des manifestations éclatent malgré "l'état de siège" en Guinée
# 968  Étude: Plus d'enfants exposés au porno en ligne
# 969  Beyonce nouvelle SI cover girl bikini
# 970  La marijuana aide à soulager la douleur nerveuse liée au VIH, selon une étude
# 971  Serena manque le tournoi de Bangalore
# 972  Une sécheuse responsable du feu tuant 39 chats et chiens
# 973  Roddick et Murray marquent à San Jose
# 974  Conflit de marque Apple réglé
# 975  Les courtiers en ligne américains regardent la Chine
# 976  Les États-Unis détournent des troupes pour combattre les talibans
# 977  Décès de Ian Richardson, acteur de 'House of Cards'
# 978  Un chef taliban tué dans une frappe aérienne
# 979  S'échapper à Prague sans les hordes d'été
# 980  Katmandou: première neige en 63 ans
# 981  Nasdaq échoue dans l'offre de LSE
# 982  Un ex-pasteur condamné à mort
# 983  Un bébé né sur un péage après que papa soit absent
# 984  Etude des liens chimpanzés et 'marteaux'
# 985  UN-Google Earth map climate change
#
#                                                         clean_text  lex_anger  \
# 0    test prédire rechute cancer sein approuvé                      0.166667
# 1    allié saddam hussein pendu selon responsable irakien           0.000000
# 2    vues sons                                                      0.000000
# 3    schuey voit ferrari dévoiler nouvelle voiture                  0.000000
# 4    clôtures annulations meilleurs conseils cas d’épidémie grippe  0.111111
# 5    camions avalés effondrement métro                              0.000000
# 6    lettre sarkozy surprend audience dessins animés français       0.000000
# 7    construire monument fils enfant fois                           0.000000
# 8    législateur veut interdire ipod passages piétons new york      0.125000
# 9    diabetic attend lunettes pendant mois                          0.000000
# 10   soudan demande envoyé nations unies partir heures              0.000000
# 11   ans après couple toujours bras                                 0.000000
# 12   défense conteste crédibilité russert                           0.250000
# 13   ozzy héros masses hard rock                                    0.000000
# 14   résumé essais fuite cia                                        0.000000
# 15   film danse prend dessus numéro                                 0.000000
# 16   nations asiatiques demandent réforme myanmar                   0.000000
# 17   après voyage irak clinton propose limites guerre               0.142857
# 18   morts immeuble feu                                             0.000000
# 19   sueur masculine augmente niveaux hormones femmes               0.000000
# 20   signaux mitigés carphone warehouse                             0.000000
# 21   démocrates complotent censurer troupes bush                    0.200000
# 22   cisco poursuit apple contre nom iphone                         0.166667
# 23   star bb jackson nie commentaires goody                         0.000000
# 24   inter milan set serie win record                               0.000000
# 25   us airways augmente offre delta                                0.000000
# 26   presse voit espoir négociations mecque                         0.000000
# 27   fan bears perd pari change nom                                 0.000000
# 28   buste anneau pornographique national majeur international      0.000000
# 29   indice cheveux humains chasse avion ligne                      0.333333
# ..                                         ...                           ...
# 956  appel frénétique affaire ryan neal                             0.400000
# 957  succès durant emporte gators                                   0.000000
# 958  scientifique fouine journal astronautes                        0.000000
# 959  fondateurs youtube partagé millions dollars                    0.000000
# 960  nation africaine espère whoopi pourra aider                    0.000000
# 961  united accrocher six points avance                             0.000000
# 962  avocat empare maison smith bahamas                             0.200000
# 963  super show prince trop révélateur                              0.200000
# 964  clijsters cherche long revoir                                  0.000000
# 965  neige trop profonde motoneiges                                 0.000000
# 966  étude phoques difficiles sujet partenaires                     0.200000
# 967  roundup manifestations éclatent malgré état siège guinée       0.142857
# 968  étude plus enfants exposés porno ligne                         0.166667
# 969  beyonce nouvelle si cover girl bikini                          0.000000
# 970  marijuana aide soulager douleur nerveuse liée vih selon étude  0.111111
# 971  serena manque tournoi bangalore                                0.000000
# 972  sécheuse responsable feu tuant chats chiens                    0.000000
# 973  roddick murray marquent san jose                               0.000000
# 974  conflit marque apple réglé                                     0.250000
# 975  courtiers ligne américains regardent chine                     0.200000
# 976  états unis détournent troupes combattre talibans               0.166667
# 977  décès ian richardson acteur house of cards                     0.000000
# 978  chef taliban tué frappe aérienne                               0.000000
# 979  échapper prague sans hordes                                    0.500000
# 980  katmandou première neige ans                                   0.000000
# 981  nasdaq échoue offre lse                                        0.000000
# 982  ex pasteur condamné mort                                       0.000000
# 983  bébé né péage après papa absent                                0.000000
# 984  etude liens chimpanzés marteaux                                0.250000
# 985  google earth map climate change                                0.000000
#
#      lex_sadness   lex_joy  lex_fear  lex_surprise  lex_disgust  lex_neutre
# 0    0.333333     0.000000  0.333333  0.166667      0.166667     0.000000
# 1    0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 2    0.000000     0.000000  0.000000  0.000000      0.500000     0.000000
# 3    0.000000     0.000000  0.166667  0.166667      0.000000     0.000000
# 4    0.222222     0.000000  0.222222  0.111111      0.111111     0.000000
# 5    0.250000     0.000000  0.250000  0.250000      0.250000     0.000000
# 6    0.000000     0.142857  0.000000  0.000000      0.000000     0.000000
# 7    0.000000     0.200000  0.000000  0.000000      0.000000     0.000000
# 8    0.125000     0.000000  0.125000  0.000000      0.000000     0.000000
# 9    0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 10   0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 11   0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 12   0.000000     0.000000  0.250000  0.000000      0.000000     0.000000
# 13   0.000000     0.000000  0.200000  0.000000      0.000000     0.000000
# 14   0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 15   0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 16   0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 17   0.142857     0.000000  0.285714  0.142857      0.000000     0.000000
# 18   0.333333     0.000000  0.000000  0.000000      0.333333     0.000000
# 19   0.000000     0.000000  0.166667  0.000000      0.166667     0.166667
# 20   0.000000     0.000000  0.000000  0.250000      0.000000     0.000000
# 21   0.000000     0.000000  0.200000  0.000000      0.200000     0.000000
# 22   0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 23   0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 24   0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 25   0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 26   0.000000     0.000000  0.000000  0.200000      0.000000     0.000000
# 27   0.000000     0.000000  0.166667  0.166667      0.000000     0.000000
# 28   0.000000     0.000000  0.000000  0.000000      0.166667     0.000000
# 29   0.000000     0.000000  0.166667  0.000000      0.000000     0.000000
# ..        ...          ...       ...       ...           ...          ...
# 956  0.000000     0.000000  0.400000  0.400000      0.200000     0.200000
# 957  0.000000     0.250000  0.000000  0.000000      0.000000     0.000000
# 958  0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 959  0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 960  0.000000     0.166667  0.000000  0.000000      0.000000     0.000000
# 961  0.000000     0.000000  0.400000  0.400000      0.000000     0.200000
# 962  0.000000     0.000000  0.200000  0.000000      0.200000     0.000000
# 963  0.200000     0.000000  0.200000  0.200000      0.000000     0.000000
# 964  0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 965  0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 966  0.200000     0.000000  0.000000  0.000000      0.200000     0.000000
# 967  0.142857     0.000000  0.142857  0.142857      0.000000     0.142857
# 968  0.000000     0.166667  0.000000  0.000000      0.166667     0.000000
# 969  0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 970  0.111111     0.222222  0.000000  0.111111      0.111111     0.000000
# 971  0.250000     0.000000  0.000000  0.000000      0.000000     0.000000
# 972  0.166667     0.000000  0.000000  0.000000      0.000000     0.000000
# 973  0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 974  0.000000     0.000000  0.000000  0.000000      0.000000     0.250000
# 975  0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 976  0.000000     0.000000  0.166667  0.000000      0.000000     0.000000
# 977  0.142857     0.000000  0.000000  0.000000      0.000000     0.000000
# 978  0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 979  0.000000     0.000000  0.500000  0.250000      0.000000     0.000000
# 980  0.000000     0.250000  0.000000  0.000000      0.000000     0.000000
# 981  0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
# 982  0.250000     0.000000  0.000000  0.000000      0.250000     0.000000
# 983  0.166667     0.166667  0.166667  0.000000      0.000000     0.000000
# 984  0.250000     0.000000  0.250000  0.000000      0.000000     0.000000
# 985  0.000000     0.000000  0.000000  0.000000      0.000000     0.000000
#
# [986 rows x 13 columns]

# %%
#df_model.head()

# %%
X_train, X_test, y_train, y_test = train_test_split(df_model.drop('sentiment', axis=1), df_model.sentiment, test_size=0.1, random_state=37)

# %%
class ColumnExtractor(TransformerMixin, BaseEstimator):
    def __init__(self, cols):
        self.cols = cols

    def transform(self, X, **transform_params):
        return X[self.cols]

    def fit(self, X, y=None, **fit_params):
        return self

# %%
def grid_vect(clf, parameters_clf, X_train, X_test, parameters_text=None, vect=None):
    
    textcountscols = ['count_capital_words','count_emojis','count_excl_quest_marks','count_hashtags'
                      ,'count_mentions','count_urls','count_words']
    

    features = FeatureUnion([ ('pipe', Pipeline([('cleantext', ColumnExtractor(cols='clean_text')), ('vect', vect)]))]
                            , n_jobs=-1)

    
    pipeline = Pipeline([
        ('features', features)
        , ('clf', clf)
    ])
    
    # Join the parameters dictionaries together
    parameters = dict()
    if parameters_text:
        parameters.update(parameters_text)
    parameters.update(parameters_clf)

    # initiate gridsearchCV with parameters and pipline
    grid_search = GridSearchCV(pipeline, parameters, n_jobs=-1, verbose=1, cv=5)
    
    print("Performing grid search...")
    print("pipeline:", [name for name, _ in pipeline.steps])
    print("parameters:")
    pprint(parameters)

    t0 = time()
    grid_search.fit(X_train, y_train)
    print("done in %0.3fs" % (time() - t0))
    print()

    print("Best CV score: %0.3f" % grid_search.best_score_)
    print("Best parameters set:")
    best_parameters = grid_search.best_estimator_.get_params()
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))
        
    print("Test score with best_estimator_: %0.3f" % grid_search.best_estimator_.score(X_test, y_test))
    print("\n")
    print("Classification Report Test Data")
    print(classification_report(y_test, grid_search.best_estimator_.predict(X_test)))

    print("all results")
    means = grid_search.cv_results_['mean_test_score']
    stds = grid_search.cv_results_['std_test_score']
    params = grid_search.cv_results_['params']
    for mean, stdev, param in zip(means, stds, params):
        print("%f (%f) with: %r" % (mean, stdev, param))
    
    return grid_search

# %%
# Parameter grid settings for the vectorizers (Count and TFIDF)
parameters_vect = {
    'features__pipe__vect__max_df': (0.25, 0.5, 0.75),
    'features__pipe__vect__ngram_range': ((1, 1), (1, 2)),
    'features__pipe__vect__min_df': (1,2)
}

# Parameter grid settings for MultinomialNB
parameters_mnb = {
    'clf__alpha': (0.25, 0.5, 0.75)
}

# %%
mnb = MultinomialNB()

# %%
countvect = CountVectorizer()

# %%
# MultinomialNB
best_mnb_countvect = grid_vect(mnb, parameters_mnb, X_train, X_test, parameters_text=parameters_vect, vect=countvect)
# Out:
# Performing grid search...
# pipeline: ['features', 'clf']
# parameters:
# {'clf__alpha': (0.25, 0.5, 0.75),
#  'features__pipe__vect__max_df': (0.25, 0.5, 0.75),
#  'features__pipe__vect__min_df': (1, 2),
#  'features__pipe__vect__ngram_range': ((1, 1), (1, 2))}
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   11.9s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   27.8s finished
# done in 28.712s
#
# Best CV score: 0.505
# Best parameters set:
# 	clf__alpha: 0.75
# 	features__pipe__vect__max_df: 0.25
# 	features__pipe__vect__min_df: 1
# 	features__pipe__vect__ngram_range: (1, 2)
# Test score with best_estimator_: 0.465
#
#
# Classification Report Test Data
#               precision    recall  f1-score   support
#
#       colère       0.00      0.00      0.00         7
#     dégoûter       0.00      0.00      0.00         1
#         joie       0.58      0.72      0.65        43
#         peur       0.35      0.41      0.38        17
#     surprise       0.57      0.20      0.30        20
#    tristesse       0.22      0.36      0.28        11
#
#    micro avg       0.46      0.46      0.46        99
#    macro avg       0.29      0.28      0.27        99
# weighted avg       0.45      0.46      0.44        99
#
# all results
# 0.483653 (0.023609) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.492672 (0.019689) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.462232 (0.020085) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.461105 (0.024602) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.483653 (0.023609) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.492672 (0.019689) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.462232 (0.020085) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.461105 (0.024602) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.483653 (0.023609) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.492672 (0.019689) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.462232 (0.020085) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.461105 (0.024602) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.493799 (0.017872) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.500564 (0.017189) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.465614 (0.019522) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.464487 (0.024367) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.493799 (0.017872) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.500564 (0.017189) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.465614 (0.019522) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.464487 (0.024367) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.493799 (0.017872) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.500564 (0.017189) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.465614 (0.019522) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.464487 (0.024367) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.492672 (0.022054) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.505073 (0.021741) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.467869 (0.019846) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.464487 (0.017551) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.492672 (0.022054) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.505073 (0.021741) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.467869 (0.019846) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.464487 (0.017551) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.492672 (0.022054) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.505073 (0.021741) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.467869 (0.019846) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.464487 (0.017551) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}

# %%
tfidfvect = TfidfVectorizer()

# %%
best_mnb_tfidf = grid_vect(mnb, parameters_mnb, X_train, X_test, parameters_text=parameters_vect, vect=tfidfvect)
# Out:
# Performing grid search...
# pipeline: ['features', 'clf']
# parameters:
# {'clf__alpha': (0.25, 0.5, 0.75),
#  'features__pipe__vect__max_df': (0.25, 0.5, 0.75),
#  'features__pipe__vect__min_df': (1, 2),
#  'features__pipe__vect__ngram_range': ((1, 1), (1, 2))}
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:   22.3s finished
# done in 23.448s
#
# Best CV score: 0.498
# Best parameters set:
# 	clf__alpha: 0.25
# 	features__pipe__vect__max_df: 0.25
# 	features__pipe__vect__min_df: 1
# 	features__pipe__vect__ngram_range: (1, 2)
# Test score with best_estimator_: 0.455
#
#
# Classification Report Test Data
#               precision    recall  f1-score   support
#
#       colère       0.00      0.00      0.00         7
#     dégoûter       0.00      0.00      0.00         1
#         joie       0.53      0.74      0.62        43
#         peur       0.35      0.35      0.35        17
#     surprise       0.43      0.15      0.22        20
#    tristesse       0.27      0.36      0.31        11
#
#    micro avg       0.45      0.45      0.45        99
#    macro avg       0.26      0.27      0.25        99
# weighted avg       0.41      0.45      0.41        99
#
# all results
# 0.487035 (0.023967) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.498309 (0.020478) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.459977 (0.026074) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.462232 (0.024612) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.487035 (0.023967) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.498309 (0.020478) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.459977 (0.026074) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.462232 (0.024612) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.487035 (0.023967) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.498309 (0.020478) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.459977 (0.026074) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.462232 (0.024612) with: {'clf__alpha': 0.25, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.491545 (0.026046) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.481398 (0.018542) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.470124 (0.030937) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.472379 (0.031116) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.491545 (0.026046) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.481398 (0.018542) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.470124 (0.030937) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.472379 (0.031116) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.491545 (0.026046) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.481398 (0.018542) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.470124 (0.030937) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.472379 (0.031116) with: {'clf__alpha': 0.5, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.483653 (0.018612) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.459977 (0.031197) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.472379 (0.030212) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.471251 (0.031819) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.25, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.483653 (0.018612) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.459977 (0.031197) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.472379 (0.030212) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.471251 (0.031819) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.5, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.483653 (0.018612) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.459977 (0.031197) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 1, 'features__pipe__vect__ngram_range': (1, 2)}
# 0.472379 (0.030212) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 1)}
# 0.471251 (0.031819) with: {'clf__alpha': 0.75, 'features__pipe__vect__max_df': 0.75, 'features__pipe__vect__min_df': 2, 'features__pipe__vect__ngram_range': (1, 2)}

# %%
#max_df: 0.25 or maximum document frequency of 25%.
#min_df: 2 or the words need to appear in at least 2 tweets
#ngram_range: (1, 1)
#clf__alpha: 0.75
""""textcountscols = ['count_capital_words','count_emojis','count_excl_quest_marks','count_hashtags'
                      ,'count_mentions','count_urls','count_words']
    
features = FeatureUnion([('textcounts', ColumnExtractor(cols=textcountscols))
                         , ('pipe', Pipeline([('cleantext', ColumnExtractor(cols='clean_text'))
                                              , ('vect', CountVectorizer(max_df=0.25, min_df=1, ngram_range=(1,1)))]))]
                       , n_jobs=-1)

pipeline = Pipeline([
    ('features', features)
    , ('clf', MultinomialNB(alpha=0.25))
])

best_model = pipeline.fit(df_model.drop('sentiment', axis=1), df_model.sentiment)"""""
# Out:
# '"textcountscols = [\'count_capital_words\',\'count_emojis\',\'count_excl_quest_marks\',\'count_hashtags\'\n                      ,\'count_mentions\',\'count_urls\',\'count_words\']\n    \nfeatures = FeatureUnion([(\'textcounts\', ColumnExtractor(cols=textcountscols))\n                         , (\'pipe\', Pipeline([(\'cleantext\', ColumnExtractor(cols=\'clean_text\'))\n                                              , (\'vect\', CountVectorizer(max_df=0.25, min_df=1, ngram_range=(1,1)))]))]\n                       , n_jobs=-1)\n\npipeline = Pipeline([\n    (\'features\', features)\n    , (\'clf\', MultinomialNB(alpha=0.25))\n])\n\nbest_model = pipeline.fit(df_model.drop(\'sentiment\', axis=1), df_model.sentiment)'

# %%
#f_model_pos = pd.read_pickle('../data/df_model_pos_fr.p')
#best_model.predict(df_model_pos).tolist()

# %%
#df_model_neg = pd.read_pickle('../data/df_model_neg_fr.p')
#best_model.predict(df_model_neg).tolist()
