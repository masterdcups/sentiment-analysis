# %%
import pandas as pd
#!pip install googletrans

# %%
#loadDEFT2015()
df_en = pd.read_pickle("data/SemEval_EN.p")
len(df_en)
# Out:
# 1000

# %%
#!pip install goslate
import goslate
gs = goslate.Goslate()
print(gs.translate('hello world', 'fr'))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-38-9bb1e8d7b368> in <module>
#       2 import goslate
#       3 gs = goslate.Goslate()
# ----> 4 print(gs.translate('hello world', 'fr'))
#
# ~\Anaconda3\lib\site-packages\goslate.py in translate(self, text, target_language, source_language)
#     407             if isinstance(text, unicode):
#     408                 text = text.encode('utf-8')
# --> 409             return _unwrapper_single_element(self._translate_single_text(text, target_language, source_language))
#     410
#     411         JOINT = u'\u26ff'
#
# ~\Anaconda3\lib\site-packages\goslate.py in _translate_single_text(self, text, target_language, source_lauguage)
#     332             return lambda: self._basic_translate(text, target_language, source_lauguage)[0]
#     333
# --> 334         results = list(self._execute(make_task(i) for i in split_text(text)))
#     335         return tuple(''.join(i[n] for i in results) for n in range(len(self._writing)))
#     336
#
# ~\Anaconda3\lib\site-packages\goslate.py in _execute(self, tasks)
#     201         if not first_tasks[-1] or not self._executor:
#     202             for each in tasks:
# --> 203                 yield each()
#     204         else:
#     205             exception = None
#
# ~\Anaconda3\lib\site-packages\goslate.py in <lambda>()
#     330
#     331         def make_task(text):
# --> 332             return lambda: self._basic_translate(text, target_language, source_lauguage)[0]
#     333
#     334         results = list(self._execute(make_task(i) for i in split_text(text)))
#
# ~\Anaconda3\lib\site-packages\goslate.py in _basic_translate(self, text, target_language, source_language)
#     249             url += '&dt=rm'
#     250
# --> 251         response_content = self._open_url(url)
#     252         raw_data = json.loads(_empty_comma.subn('', response_content)[0].replace(u'\xA0', u' ').replace('[,', '[1,'))
#     253         data = {'src': raw_data[-1][0][0]}
#
# ~\Anaconda3\lib\site-packages\goslate.py in _open_url(self, url)
#     189                     print(threading.currentThread(), e)
#     190                 if 'Connection reset by peer' not in str(e):
# --> 191                     raise e
#     192                 exception = e
#     193                 time.sleep(0.0001)
#
# ~\Anaconda3\lib\site-packages\goslate.py in _open_url(self, url)
#     179         for i in range(self._RETRY_TIMES):
#     180             try:
# --> 181                 response = self._opener.open(request, timeout=self._TIMEOUT)
#     182                 response_content = response.read().decode('utf-8')
#     183                 if self._DEBUG:
#
# ~\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\Anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# ~\Anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~\Anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 503: Service Unavailable

# %%
from googletrans import Translator

translator = Translator()

#print(len('hello.'))
translated_text = translator.translate('hello', src='en', dest='fr')
print(translated_text.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-37-3b5de29f82a2> in <module>
#       4
#       5 #print(len('hello.'))
# ----> 6 translated_text = translator.translate('hello', src='en', dest='fr')
#       7 print(translated_text.text)
#
# ~\Anaconda3\lib\site-packages\googletrans\client.py in translate(self, text, dest, src)
#     170
#     171         origin = text
# --> 172         data = self._translate(text, dest, src)
#     173
#     174         # this code will be updated when the format is changed.
#
# ~\Anaconda3\lib\site-packages\googletrans\client.py in _translate(self, text, dest, src)
#      79         r = self.session.get(url, params=params)
#      80
# ---> 81         data = utils.format_json(r.text)
#      82         return data
#      83
#
# ~\Anaconda3\lib\site-packages\googletrans\utils.py in format_json(original)
#      60         converted = json.loads(original)
#      61     except ValueError:
# ---> 62         converted = legacy_format_json(original)
#      63
#      64     return converted
#
# ~\Anaconda3\lib\site-packages\googletrans\utils.py in legacy_format_json(original)
#      52             text = text[:p] + states[j][1] + text[nxt:]
#      53
# ---> 54     converted = json.loads(text)
#      55     return converted
#      56
#
# ~\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
#df_fr['texte'] = translator.translate(df_en[0], dest='fr').text

#print(translator.translate(x[0], dest='fr').text)
#print(translator.translate(x[1], dest='fr').text)

#for t in df_en[0]:
   # translated_text = translator.translate('hello.', src='en', dest='fr')
   # print(t)
    #df_fr.append({'texte': }, ignore_index=True)
#df_fr['sentiment'] = [translator.translate(x, dest='fr').text for x in df_en[1]]

# %%
import copy
from googletrans import Translator

df_fr = pd.DataFrame() 
count = 0
for index, row in df_en[911:].iterrows():
    # REINITIALIZE THE API
    translator = Translator()
    newrow = copy.deepcopy(row)
    #print(newrow)
    try:
            # translate the 'text' column
            text_translated = translator.translate(row[0], dest='fr')
            print(text_translated.text)
            sentiment_translated = translator.translate(row[1], dest='fr')
            print(sentiment_translated.text)
            df_fr = df_fr.append({'text': text_translated.text, 'sentiment': sentiment_translated.text}, ignore_index=True)
    except Exception as e:
        print(str(e))
        continue
df_fr
# Out:
# Un test pour prédire la rechute du cancer du sein est approuvé
# joie
# Un allié de Saddam Hussein est pendu, selon un responsable irakien
# tristesse
# Vues et sons du CES
# joie
# Schuey voit Ferrari dévoiler une nouvelle voiture
# joie
# Les clôtures et les annulations sont les meilleurs conseils en cas d’épidémie de grippe
# peur
# Camions avalés dans l'effondrement du métro
# tristesse
# Une lettre de Sarkozy surprend l'audience sur les dessins animés français
# surprise
# Construire un monument à un fils, un enfant à la fois
# tristesse
# Un législateur veut interdire les iPod dans les passages pour piétons à New York
# surprise
# Diabetic attend des lunettes pendant des mois
# tristesse
# Le Soudan demande à l'envoyé des Nations Unies de partir dans 72 heures
# surprise
# 5000 ans après, mais un couple est toujours dans les bras
# surprise
# La Défense conteste la crédibilité de Russert
# surprise
# Ozzy, un héros pour les masses hard rock
# joie
# Résumé des essais de fuite de la CIA
# surprise
# Le film de danse prend le dessus sur le numéro 1
# joie
# Les nations asiatiques demandent la réforme du Myanmar
# surprise
# Après le voyage en Irak, Clinton propose des limites de guerre
# joie
# 7 morts dans un immeuble en feu
# tristesse
# La sueur masculine augmente les niveaux d'hormones des femmes
# surprise
# Les signaux mitigés de Carphone Warehouse
# surprise
# Les démocrates complotent de censurer les troupes de Bush
# surprise
# Cisco poursuit Apple contre le nom de l'iPhone
# colère
# La star de BB Jackson nie les commentaires de Goody
# dégoûter
# Inter Milan set Serie A win record
# joie
# US Airways augmente son offre pour Delta
# surprise
# La presse voit de l'espoir dans les négociations à la Mecque
# joie
# Le fan des Bears perd son pari et change de nom
# surprise
# Buste d'anneau pornographique national majeur international
# dégoûter
# Indice 'cheveux humains' dans la chasse pour avion de ligne
# surprise
# Johnny Depp tourne un film sur l'empoisonnement des espions
# joie
# Vraiment ?: L'affirmation: la pilule peut vous faire prendre du poids
# surprise
# 5 métamorphoses d'argent
# joie
# Le SCT doit payer une amende de 2 millions de dollars pour avoir fait peur à la campagne publicitaire
# peur
# "Stomp the Yard" a des coups gagnants à ses débuts du week-end
# joie
# Les garçons découverts apportent le choc et la joie
# surprise
# Bernhard s'apprête à quitter Volkswagen
# tristesse
# L'audience de Jackson sur Pacers
# peur
# Cas: quand la solution simple est la bonne
# joie
# Deux groupes musulmans poursuivent le journal français International
# colère
# Golden Globes sur leur chemin
# joie
# Au New OZZFEST, la liberté n'est pas libre
# surprise
# Federer a offert un solide match nul australien
# tristesse
# Les manifestants mettent fin à la grève alors que le Premier ministre népalais concède ses revendications
# joie
# Turner paie pour "le bombardement" de Boston
# peur
# Deux personnes détenues dans un envoi postal
# dégoûter
# Essai: à propos de cette mauvaise série: la psychiatrie ne peut pas faire grand chose
# tristesse
# La nièce de Hussein plaide pour la vie du père
# tristesse
# Sarkozy en tête d'affrontement dans la série de dessins animés
# colère
# Téléchargement du réseau mondial de suspects de viol d'enfant
# colère
# Blake bat Moya pour conserver son titre
# joie
# Les tempêtes tuent, coupent le courant, annulent les vols
# peur
# L'aquarium endort un béluga souffrant
# tristesse
# Microsoft, Sony, nous avons un problème
# surprise
# Un état policier? Les problèmes
# peur
# Déplacer pour interdire aux iPod de traverser la rue
# surprise
# Le Taj Mahal en Inde fait peau neuve
# joie
# Cheney au Congrès: Impossible de mener la guerre en Irak par comité
# colère
# Ganguly a passé l'appel de l'équipe indienne
# joie
# Fortune: regarder au-delà de l'iPhone
# joie
# Vraiment ?: La prétention: la banquette arrière d'une voiture est l'endroit le plus sûr pour s'asseoir
# surprise
# Le mandat de vaccination contrarie les législateurs
# colère
# Analyse d'actualité: la fierté iranienne mise à l'épreuve
# peur
# La commission publie un rapport sombre sur le changement climatique
# peur
# L'American Idol virtuel prend les bonnes notes
# joie
# Un attentat à la voiture piégée en Irak fait 22 morts et plus de 60 blessés
# tristesse
# «Stomp» fait le numéro 1 au box-office
# joie
# Un cadre de Google agit en tant qu'envoyé de bonne volonté
# joie
# Une Philippine enlevée au Nigeria
# peur
# Les Seahawks et les Bears se disputent le titre NFL
# joie
# Brown n'est pas enterré comme des problèmes de succession
# tristesse
# Rob Cohen dirigera-t-il la troisième «maman»?
# surprise
# L'UE va demander à la Chine de passer au vert
# joie
# Remède du XVIIe siècle; Puissance du 21ème siècle
# surprise
# Les prévisionnistes s'attendent à 2007 bien chaud
# peur
# «Sunshine» Goydos gagne Sony ouvert
# joie
# Enseignant accusé d'agression sexuelle
# dégoûter
# Merck: Gardasil pourrait combattre plus de souches
# joie
# Selon les Nations Unies, les glaciers de montagne fondent plus rapidement
# peur
# La neige provoque des fermetures d'aéroports en Grande-Bretagne
# tristesse
# Bananaconda inventeur est le meilleur poète des enfants
# joie
# Les actionnaires poursuivent Apple
# colère
# Les Israéliens ripostent après l'attaque de l'armée libanaise
# peur
# Grippe aviaire confirmée chez des dindons britanniques
# peur
# Trop peu de sommeil peut signifier des enfants trop gros
# surprise
# Bain maman se réveille pour retrouver un bébé mort
# tristesse
# Les visiteurs de la Tour Eiffel grimpent pour enregistrer en 2006
# joie
# Plus de sommeil, des enfants plus minces et en meilleure santé
# surprise
# La reine se bat contre Baftas
# joie
# Walters on Trump: 'Homme pauvre et pathétique'
# tristesse
# La tempête de verglas frappe les routes, le pouvoir
# peur
# L'Iran dit qu'il frappera les intérêts américains s'il était attaqué
# peur
# Les factions palestiniennes doivent reprendre les pourparlers
# joie
# Étude: la sueur des hommes provoque une forte excitation sexuelle chez les femmes
# surprise
# Les essais nucléaires à la Corée du Nord
# peur
# La Russie envisage de renforcer son armée
# peur
# Des archéologues découvrent les restes d'un couple enlisé dans un câlin
# surprise
# Stenson défend son titre à Dubaï
# joie
# Se jeter à l'eau
# peur
# Mises à jour sur les meilleures histoires du monde
# joie
# L'homme monte à vélo stationnaire pendant 85 heures
# surprise
# Enduit de verglas Midwest
# peur
# Une Mistrial pour le Lieut. Watada
# colère
# L'Iran met en garde contre les Etats-Unis s'il est attaqué
# peur
# Fin des pourparlers sur l'ASEAN sur la sécurité énergétique
# joie
# Le nombre de morts irakiens a dépassé 34 000 en 2006, selon les Nations Unies
# tristesse
# Israël intensifie ses vols militaires au-dessus du Liban
# peur
# Nouveaux gadgets à profusion au salon de la technologie
# joie
# Une autre mort à Georgia Aquarium
# tristesse
# Les Etats-Unis exhortent l'offensive afghane du printemps de l'OTAN
# peur
# Les lettres piégées britanniques pourraient provenir de conducteurs extrémistes
# peur
# L'Asie cherche à percer en Corée du Nord
# surprise
# Federer surmonte un départ en lambeaux
# joie
# Les fans de Rowdy expulsés de l'Open
# colère
# Les manifestants du Terai saluent la victoire "historique" du gouvernement
# joie
# Colère à la libération de deux personnes détenues au-dessus d'un complot de décapitation
# colère
# Bush inflexible sur les troupes en Irak
# colère
# Bebe Neuwirth arrive à se "remuer"
# joie
# Beckham to L.A .: Pour le jeu pas la gloire
# joie
# Dormez plus pour combattre l'obésité chez les enfants
# surprise
# Abbas refuse l'état temporaire
# tristesse
# L'enquête sur un site de pédopornographie touche 77 pays
# dégoûter
# Sleuths se rapproche d'Ulysse
# surprise
# Variété: Johnny Depp tourne un film sur l'empoisonnement d'un espion
# surprise
# La tempête de verglas paralyse le centre des États-Unis
# peur
# Park tient le premier rôle
# joie
# Roméo et Juliette préhistorique découverts
# surprise
# Le célèbre monument de l'Inde fait peau neuve
# joie
# Le nouveau départ de Joseph Wambaugh
# joie
# Décès d'un participant au concours de consommation d'eau
# tristesse
# Apple lâche une bombe avec son iPhone
# surprise
# 'Brangelina' de Bollywood fiancée
# joie
# Irak: des combattants chiites arrêtés dans le cadre de la répression
# peur
# Journal de Rio De Janeiro: tracer des lignes sur le sable, entre les classes
# tristesse
# Les directives de santé des modèles - vont-elles aider?
# surprise
# Remonter le temps à la station de ski
# joie
# Un joueur de cricket condamné pour avoir tué
# tristesse
# Les noix combattent les graisses malsaines
# joie
# Apple à la mise à niveau de Vista: 'Wait'
# surprise
# Sarwan blessé manquera une journée
# tristesse
# Entreprises en alerte aux lettres piégées
# peur
# Les studios approuvent les téléchargements de films
# surprise
# Asif est de retour avec quatre courses au guichet
# joie
# Bush a autorisé l'arrestation d'Iraniens en Irak, selon Rice
# colère
# Australie: le scandale de la bague porno
# dégoûter
# Le vice-ministre de la Santé arrêté lors d'un raid américano-irakien
# tristesse
# Le sénateur Carl Krueger pense que les iPod peuvent vous tuer
# surprise
# Enfin, le Sénat approuve le projet de loi antiterroriste de Manille
# joie
# La Somalie déclare l'état d'urgence
# peur
# Matt brille avec sa finition alpine
# joie
# Browne, PDG de BP, quittera ses fonctions en juin
# tristesse
# Un iPhone sous un autre nom? Sûrement pas
# surprise
# La vie à Gaza s'aggrave progressivement
# tristesse
# Le défi énergétique | Visions exotiques: comment refroidir une planète (peut-être)
# surprise
# Des moyens faciles d'économiser (vraiment) 400 000 $
# joie
# Les actionnaires poursuivent Apple
# colère
# Constatations: l'humanité peut-elle survivre? Voulez-vous parier dessus?
# peur
# L'Iran augmente sa production d'uranium de qualité militaire
# peur
# Cargaison menace de gréement remorqué à terre
# peur
# Les Palestiniens disent que les affrontements ont nui à leur cause
# tristesse
# La sueur masculine peut produire des hormones
# surprise
# Signes vitaux: Risques: antidépresseur lié aux fractures chez les personnes âgées
# surprise
# Peron a tenu des violations des droits de l'homme des années 70
# tristesse
# La recherche dans la vie spatiale se tourne vers la télévision
# surprise
# Annonces du Super Bowl sur la violence caricaturale, reflétant peut-être le bilan de la guerre
# tristesse
# YouTube a dit de laisser tomber la vidéo de sexe de célébrités
# surprise
# Beckham & Posh et plus de couples athlètes-célébrités
# joie
# La ville installe des abris de tempête de verglas
# peur
# Les procureurs de Libby attendent les décisions du juge
# tristesse
# Avis: 'Alpha Dog' passe à côté de l'essentiel
# tristesse
# Les républicains envisagent de bloquer le débat sur l'Irak
# colère
# Réactions mitigées face à la poussée de la Chine en Afrique
# surprise
# Neigé dans les Rocheuses canadiennes
# joie
# Évitez les douches: la sueur masculine excite les femmes, selon une étude
# surprise
# La feuille des paroles de Gently Weeps est en vente
# joie
# Canete remporte le premier Open Joburg
# joie
# Un groupe de défense des droits de l'homme arrête de violentes grèves au Népal
# joie
# Real souffre du revers de sa blessure à Carlos
# tristesse
# L'astronaute a peut-être bouclé sous le stress
# tristesse
# Des hommes armés enlèvent une Philippine au Nigéria
# peur
# Fan de l'année de l'équipe de la NFL: 'Flag Lady'
# joie
# Non 10 rejette la demande de l'Etat policier
# surprise
# L'AirAsia X de Malaisie volera en juillet
# joie
# 10 kidnappés à la base pétrolière du Nigeria
# peur
# Sueur mec est aimant bébé
# surprise
# Le tourisme urbain en plein essor en Afrique du Sud
# joie
# 'Alpha Dog' passe à côté de l'essentiel
# surprise
# Iran leader pays Nicaragua a visit
# surprise
# "Grey's", "Pirates" en tête du choix du peuple
# joie
# Réseau de terreur
# peur
# Maintenant c'est officiel: l'Irak est en désordre
# tristesse
# La neige engendre la misère du voyage en Angleterre
# tristesse
# Le fils de James Brown âgé de 5 ans laissé sans volonté
# surprise
# Deux hommes tués par le métro de Londres
# tristesse
# Des millions de dollars US n'achètent pas d'influence dans le jeu meurtrier au pouvoir
# tristesse
# Les ministres de l'OLP sont convenus à la Mecque
# joie
# L'escadron s'excuse pour la mort d'un "tir ami"
# tristesse
# La violence à la Nouvelle-Orléans suscite les craintes du tourisme
# peur
# Pilote de tir ami "expérimenté"
# peur
# SPACE.com: Triplets de trous noirs repérés
# surprise
# Vaccins: mandat ou choix?
# surprise
# Emeute de soldats congolais, butin sur une question de solde
# colère
# Les matières premières mènent l'Europe plus haut
# joie
# La transpiration masculine augmente les niveaux d'hormones des femmes
# surprise
# Goetschl met fin à la sécheresse en Autriche
# joie
# Horloge du jour maudit
# peur
# Des troupes se massent autour de la ville somalienne
# peur
# Tariq Ramadan a un problème d'identité
# surprise
# Peretz ordonne aux FDI de réagir avec force aux attaques sur la frontière nord
# colère
# Un train s'écrase près d'une station balnéaire thaïlandaise
# tristesse
# Le Hamas et le Fatah rentrent dans l'unité: le gouvernement parle à La Mecque
# joie
# Le rallye de Pats au quatrième trimestre termine les chargeurs
# joie
# 7 morts alors qu'un hélicoptère américain s'écrase en Irak
# tristesse
# Millionaire secret Santa dies
# tristesse
# Morrissey pourrait égayer l'Eurovision
# joie
# Les valeurs chrétiennes guident Dungy et les Colts
# joie
# La tirade d'une femme israélienne suscite l'indignation du Premier ministre
# colère
# Passer des échanges devient un point d'éclair politique
# colère
# La police enquête sur deux incendies dans une église
# tristesse
# L'Italie jugera un soldat américain responsable de la mort de son agent en Irak
# colère
# Depp dans le film d'espionnage d'espionnage
# joie
# 24 'Jack' revient
# joie
# US Airways augmente son offre pour Delta
# surprise
# Même avant sa publication, le rapport mondial sur le climat est jugé trop optimiste
# peur
# La deuxième pendaison a également mal tourné
# tristesse
# Howell prend un coup d'avance dans Sony Open
# joie
# Les contrôles psychologiques examinés après le craquement de l'astronaute
# tristesse
# Le test de Pap, l'un des piliers du cancer du col de l'utérus, pourrait s'effacer
# surprise
# Martins mène la bataille de Newcastle
# joie
# PS3 cher mais impressionnant
# joie
# La vengeance de Pluton: le prix du «mot de l'année»
# joie
# Agence spatiale européenne
# joie
# Les pirates attaquent des serveurs Internet clés
# colère
# Hussein co-accusés exécutés
# tristesse
# Mémo de Francfort: l'Allemagne revit la terreur des années 1970 alors que deux personnes cherchent à être libérées de prison
# peur
# S'amuser à Ojai
# joie
# Houston, elle a des problèmes
# tristesse
# Amazon.com a "les meilleures ventes"
# joie
# Les pirates attaquent les serveurs racine
# colère
# Les jeux vidéo peuvent améliorer votre vision
# surprise
# Internet attaqué! (Quelqu'un at-il remarqué?)
# surprise
# À Washington, les entrepreneurs jouent le plus grand rôle de tous les temps
# surprise
# Des inondations forcent des évacuations en Malaisie
# tristesse
# Sur MySpace, les filles cherchent des amis, les garçons flirtent
# surprise
# Tests de médicament pour bloquer H.I.V. l'infection est stoppée par la sécurité
# peur
# Zoo ours polaire d'avoir canal
# tristesse
# L'Europe prend la tête du Trophée Royal
# joie
# Israël va installer des caméras pour montrer des images en direct de Mughrabi
# joie
# "Nous avons allumé notre dernière bougie hier"
# tristesse
# Google achète YouTube pour 1,65 milliard de dollars
# surprise
# PSP numéro un de la plateforme Sony au Japon
# joie
# Angleterre inclure Giles dans l'équipe de WC
# joie
# Beckham ne jouera plus pour le Real
# tristesse
# Huit ans pour les tueurs de Damilola
# tristesse
# Un éditeur de PC World tué à la maison en Californie
# tristesse
# Les mains sur 'Doomsday Clock' avancent
# peur
# Zach Braff dit qu'il a une «dépression légère»
# tristesse
# L'enquête sur un site pédopornographique touche 77 pays, USA Today
# dégoûter
# Un panel scientifique appelle le réchauffement climatique sans équivoque
# peur
# Nouvelles Baby pandas! Bébés pandas! Bébés pandas!
# joie
# Préparez-vous pour les gains
# joie
# L'Allemagne agonise après la fuite des cerveaux
# tristesse
# Les dirigeants iraniens et nicaraguayens se rencontrent
# joie
# Hôtels secrets dans la campagne irlandaise
# surprise
# Vins fins en Colombie-Britannique
# joie
# Le président philippin se félicite de l'approbation par le Sénat d'un projet de loi antiterroriste
# joie
# Un petit avion s'écrase au décollage, faisant 2 morts
# tristesse
# Des rats plus gros et plus agressifs infestant le Royaume-Uni
# peur
# Voyage + loisirs: prochain point chaud de l'île: Sainte-Lucie
# joie
# Leaders rock Real Mallorca Séville
# joie
# La fierté iranienne d'enrichir de l'uranium est mise à l'épreuve
# peur
# Santé personnelle: pour les adolescents, la voiture est la zone de danger
# peur
# Les observateurs d'oiseaux affluent pour voir un hibou rare
# joie
# Eye on cosmos est perdu pour court-circuiter sur hubble
# tristesse
# Trop jeune pour cela: faire face au cancer chez les moins de 40 ans
# tristesse
# Un groupe nommé par un nouveau président
# joie
# Le ministre critique les compagnies aériennes sur le carbone
# colère
# Un optimisme rare alors que les pourparlers sur la Corée du Nord atteignent un carrefour
# joie
# Un homme décapité dans le sud de la Thaïlande
# tristesse
# Le «scénario cauchemardesque» de la Chine
# peur
# Un concours de plongée annuel en Corée du Sud: un défi de taille
# surprise
# Blair dit qu'il regrette les retards dans l'enquête du soldat britannique
# tristesse
# Les forces irakiennes arrêtent un responsable soupçonné d'avoir participé à un complot chiite
# peur
# Wellcome récompense la recherche anti-graisse
# joie
# Croisons les doigts pour la Corée du Nord
# joie
# Aucune intention de guerre avec l'Iran, selon les Etats-Unis
# joie
# À quoi Newsom fait-il face après le scandale
# peur
# La baby-sitter Globes de Maggie Gyllenhaal: Maman
# joie
# Alors que l'inflation monte en flèche, l'économie du Zimbabwe plonge
# tristesse
# Gage: j'ai été maltraité dans le bizutage de fraternité
# dégoûter
# Experts: Peur probablement enchaîné garçon
# peur
# Qu'est-ce qui se cache derrière l'hélicoptère s'écrase en Irak
# peur
# Un suspect terroriste musulman libéré affirme que la Grande-Bretagne est un "Etat policier"
# peur
# Blair s'excuse pour son enquête sur des tirs amis
# tristesse
# Depp 'fera le film Litvinenko'
# joie
# Pourquoi le gaz suit le pétrole mais pas le bas
# surprise
# 'Cravings' toujours là, sez Tara
# joie
# Le projet de loi dépouillerait les législateurs reconnus coupables des pensions
# tristesse
# Les ours regardent comme le plomb s'échappe
# tristesse
# En raison de la dépendance, une lésion cérébrale arrête de fumer
# surprise
# En test rigoureux, la thérapie du dialogue fonctionne pour le trouble panique
# joie
# Rice: les États-Unis ne vont pas débrancher l'Irak
# joie
# En route vers l'indépendance du Kosovo, un avertissement: allez-y doucement
# peur
# Mistrial pour l'officier qui a refusé d'aller en Irak
# tristesse
# Les rebelles rejoignent le parlement népalais
# surprise
# EMI met en garde sur les profits, le patron s'en va
# peur
# Effondrement de métro filmé
# tristesse
# Stinky mais true: la sueur des hommes est faite pour l'amour
# surprise
# POLITIQUE-ÉTATS-UNIS: sursis pour l'officier qui a dénoncé la "guerre immorale"
# joie
# Les chasseurs arpentent les arbres les plus hauts du monde
# tristesse
# Un déversement de carburant peut entraîner une perte de jet
# peur
# Sri Lanka: les inondations déplacent 60 000 personnes
# tristesse
# Justin Timberlake et Cameron Diaz annoncent une scission
# tristesse
# L'Iran doit toucher les intérêts américains s'il est attaqué
# peur
# Israël espère pouvoir garder la frontière libanaise
# joie
# Cisco poursuit Apple contre le nom de l'iPhone
# colère
# Deux Palestiniens tués près d'une clôture
# tristesse
# Le PDG d'EarthLink décède à 49 ans
# tristesse
# Une star meurt, une querelle de famille est née
# tristesse
# Carter était une catastrophe, a déclaré Ford
# colère
# Le MVP du Super Bowl, Manning, insiste sur le fait qu’il est l’un des types
# joie
# Santé personnelle: l'importance de savoir de quoi le médecin parle
# peur
# Israël Peretz demande la cessation de la construction litigieuse de Jérusalem
# colère
# Peter Jackson ne travaillera plus jamais pour moi
# colère
# Les États-Unis maintiennent les options ouvertes à l'Iran
# joie
# Les actions européennes atteignent de nouveaux sommets
# joie
# Pour les femmes, rien ne vaut l'odeur de la sueur des hommes
# surprise
# Regarder au-delà de l'iPhone
# surprise
# Libération d'un suspect: ma terreur lors d'une descente de police
# peur
# Au loin, les perdants du Super Bowl seront des champions
# joie
# Une femme meurt après la consommation excessive d'eau
# tristesse
# Mancuso suscite les célébrations américaines
# joie
# L'ANASE demande la résolution de la Corée du Nord
# peur
# Une pénalité de retard coûte à la Roma les points
# tristesse
# Mistrial déclaré dans une affaire de viol enseignant-élève
# tristesse
# La joie des mots 'Bookworm Adventures'
# joie
# Kylie se sépare
# tristesse
# iPod bon pour les jeux vidéo
# joie
# Revue: virtuel 'American Idol' frappe à droite
# joie
# Léo se bat
# joie
# Les avocats pointent du doigt dans la bagarre entre Ryan O'Neal et son fils
# colère
# John Grisham prêt pour le drame judiciaire
# peur
# Bill Gates et Craig Mundie: vista is Secure, les employés ne le sont pas
# surprise
# La faute des Irakiens a retardé l'attaque d'un plan américain
# colère
# Les scouts accusés d'avoir déclenché une traînée de poudre
# peur
# China urges UN action on N Korea
# peur
# Scorpion dans un avion, une culotte de douleur
# peur
# La sueur masculine augmente les niveaux d'hormones des femmes
# surprise
# Mbeki lors de la grande visite des Chinois
# surprise
# Sarkozy nommé par la droite française
# joie
# Les affrontements israélo-libanais à la frontière
# peur
# La Corée du Nord revendique un essai nucléaire
# peur
# Début des pourparlers sur les soldats de la paix somaliens
# joie
# Les jeux d'action améliorent la vue
# surprise
# Une petite partie du cerveau et ses effets profonds
# surprise
# Les forces de défense israéliennes pilonnent les positions de l'armée libanaise à la frontière nord
# peur
# Thaïlande: il manque 25 ans après avoir pris le mauvais bus
# tristesse
# Une ballerine suscite une querelle antifasciste
# colère
# L'essor de l'Internet en Chine repose sur le divertissement virtuel
# joie
# Review: PS3 cher mais impressionnant
# joie
# Les commandes de machines poussent l'Asie à la hausse
# joie
# 'Lost' Fox ': Je suis un menteur et un tricheur'
# dégoûter
# La Russie va renforcer sa force militaire
# peur
# Au procès Libby, Russert de NBC donne et obtient
# peur
# La Corée du Nord est prête à discuter des premières étapes de la résolution nucléaire
# joie
# Victime: un homme armé a acheté un verre après avoir tiré
# surprise
# Ferrer victorieux en duel espagnol
# joie
# Les travailleurs britanniques sont en alerte pour des lettres piégées
# peur
# La NASA a-t-elle tué accidentellement la vie sur Mars?
# surprise
# Un nouveau vaccin contre le cancer du col utérin pourrait aussi être utile chez les hommes
# joie
# Rechercher des victimes de l'effondrement du métro
# tristesse
# Une erreur humaine a provoqué un crash d'Helios
# tristesse
# Les États-Unis inciteront les alliés de l'OTAN à avoir plus de soldats pour vaincre les talibans
# peur
# Microsoft prend en charge le standard d'authentification OpenID
# joie
# Aucun acheteur en vue pour Napster
# tristesse
# En bref: iPod préchargés, films Wal-Mart, magasins Apple
# joie
# La Chine estime que les pays riches devraient jouer un rôle moteur dans le réchauffement climatique
# tristesse
# La Corée du Nord pourrait commencer à démanteler ses armes nucléaires
# joie
# Traquer les crimes de haute technologie
# joie
# Barack Obama annonce officiellement sa candidature au poste de président
# joie
# Des ravisseurs en saisissent deux au Nigeria
# peur
# L'Indonésie peut vendre, et non donner, le virus de la grippe aviaire à des scientifiques
# peur
# Une vidéo d'attaque attriste la "veuve au feu ami"
# tristesse
# L'Europe conserve son trophée avec une grosse victoire
# joie
# Accessoires de pointe pour lecteurs de musique numériques
# joie
# La tempête de verglas s'abat sur le centre des États-Unis
# peur
# La neige engendre la misère du voyage en Angleterre
# tristesse
# Indonésie: 340 000 victimes des inondations
# tristesse
# Le ministre irakien de la Santé saisi lors d'un raid
# surprise
# La tempête de verglas amène le chaos aux États-Unis
# peur
# Mystère de fleur puante résolu
# joie
# Un membre du Congrès réprimande les alliés américains pour leur manque de soutien en Afghanistan
# colère
# Roddick bat Federer en finale
# joie
# Roméo et Juliette préhistorique découverts
# joie
# Donald et Goydos se partagent la tête de Sony
# joie
# Les Etats-Unis et les Irakiens se disputent pour des projets de guerre
# peur
# Recherche en mer d'un scientifique Microsoft manquant
# tristesse
# L'Iran doit toucher les intérêts américains s'il est attaqué
# peur
# Blair: La bataille terroriste sera longue
# peur
# Ourson retourné dans le désert
# joie
# La croissance des ventes de Carrefour est insuffisante
# tristesse
# Allié aux démocrates, Lieberman s'allie facilement aux républicains
# surprise
# Dans les Rocheuses, les pins meurent et les ours le sentent
# tristesse
# L'Iran va frapper les intérêts américains s'il est attaqué
# peur
# Couvre-seins, autres secrets de star
# dégoûter
# Apple: pas d'iTunes pour vous si vous avez Vista!
# surprise
# Cheminées dans un désert blanc divisent l'Islande
# tristesse
# Ça te coûtera
# colère
# Irak: le sectarisme accéléré
# peur
# La sueur masculine soulève des hormones féminines
# surprise
# 7 sénateurs du GOP vont forcer le débat sur les troupes en Irak
# joie
# Le Bangladesh met fin au couvre-feu au milieu des troubles
# joie
# Conflit entre l'Italie et les États-Unis à propos du tir de l'Irak
# colère
# Voici les globes!
# joie
# La neige provoque le chaos des transports en Grande-Bretagne
# tristesse
# La neige provoque des fermetures d'aéroports en Grande-Bretagne
# tristesse
# Deuxième avis: fille ou garçon? à mesure que la technologie de la fécondité progresse, un débat éthique se poursuit
# surprise
# Une neige abondante provoque le chaos des voyages et ferme les écoles
# peur
# L'héritage de Barbaro: sauver les autres chevaux
# joie
# Le luxe creuse dans le Lowcountry en Caroline du Sud
# joie
# Des dizaines de morts dans l'attentat de Bagdad
# tristesse
# Les tempêtes de verglas font 21 morts dans le pays
# tristesse
# De Villiers takes over Dakar lead
# joie
# Le Vietnam devient le 150ème membre de l'OMC
# joie
# Le trio sud-africain partage un avantage
# joie
# Observatoire: le poison engendre le poison
# peur
# L'intensité de l'action stimule la vision
# joie
# Pourquoi l'odeur de l'aisselle d'un homme est-elle allumée?
# surprise
# Nokia 5300 Xpress Music
# joie
# Dell pour réduire les bonus, la gestion de la coupe
# tristesse
# La deuxième baisse des décès par cancer pourrait indiquer une tendance, selon des chercheurs
# surprise
# Les jeux télévisés deviennent interactifs
# joie
# Garçon disparu depuis 2002 retrouvé vivant
# joie
# Les Etats-Unis et la Corée du Nord ont signé un mémo nucléaire
# joie
# La Russie honore le designer Spoutnik
# joie
# Dans la capitale du Kenya, le danger est de plus en plus fort
# peur
# Bill, merci pour les souvenirs de la RSA ... et rigole
# joie
# Pilote de tir ami "expérimenté"
# tristesse
# MySpace accueille des amis français
# joie
# Airlines: piste d'atterrissage britannique dangereuse
# peur
# Les montants que vous devez payer pour une alerte à la bombe
# peur
# En Egypte, Rice parle doucement
# joie
# Hebdomadaire Nielsen Yvonne De Carlo, star de 'Munsters', morte
# tristesse
# Le Sénat vote pour révoquer les pensions
# tristesse
# Le PDG d'EarthLink décède à 49 ans
# tristesse
# Le géant de l'informatique SAP manque sa cible
# tristesse
# Signes vitaux: capacités mentales: l'acide folique peut améliorer les capacités de réflexion
# surprise
# De Villiers stretches overall lead
# joie
# Les familles célèbrent le retour des fils
# joie
# La Chine en détient 2 après que des parties du corps aient été retrouvées dans un courrier
# peur
# La Corée du Nord prête à discuter du désarmement nucléaire
# joie
# Pour les femmes, rien ne vaut l'odeur de la sueur des hommes
# surprise
# Nadal veut la couronne de l'Open d'Australie
# joie
# Journal de Beijing: la construction olympique met au jour un trésor antique
# joie
# Le président chinois arrive au Mozambique et la tournée africaine presque terminée
# joie
# L'auteur 'Mockingbird' reclusif assiste au spectacle
# joie
# L'Asie proche du pacte sur l'énergie et la sécurité
# joie
# La loi antiterroriste des Philippines reportée à juin
# peur
# Une ancienne suspecte condamne les lois anti-terroristes
# colère
# Une étude détecte un gène lié à la maladie d'Alzheimer
# joie
# Panda cub fait ses débuts
# joie
# Harris Haul place l'Afrique du Sud en tête
# joie
# Médicament de perte de poids à vendre en vente libre
# joie
# Beckham expose les raisons de son déménagement
# joie
# Une étude révèle que l'air graveleux augmente le risque de maladie cardiaque chez les femmes âgées
# surprise
# Le Venezuela et l'Iran combattent la domination américaine
# colère
# La star de "Housewives" Marcia Cross au repos
# tristesse
# Blog: Voici les Globes!
# joie
# La police grecque traque les assaillants de l'ambassade
# colère
# Apple avertit les utilisateurs d'iTunes d'attendre sous Vista
# surprise
# Les tsunamis craignent une atténuation après le séisme
# peur
# La Chine considère les réserves en euro-obligations
# joie
# Underarm les ramasse
# surprise
# Au moins 130 morts selon des niveaux explosifs sur le marché de Bagdad
# tristesse
# La nouvelle équipe de McCain a fait des annonces d'attaque qu'il avait déjà critiquées
# colère
# Morts causées par des poussées de grippe aviaire en Asie
# peur
# Le Hamas et les dirigeants du Fatah s'engagent à se rencontrer jusqu'à ce qu'ils parviennent à un accord
# joie
# Les officiers avaient un «rapport» avec un ravisseur présumé
# dégoûter
# Pas de livre électronique pour Harry Potter VII
# tristesse
# Critique: Nokia 5300 Xpress Music
# joie
# 'Je ne peux plus faire ça'? Pas jack
# surprise
# Triplés de trous noirs repérés
# surprise
# Israël pèse sur le webcast du projet de la vieille ville
# surprise
# Indonésie: 61 décès dus à la grippe aviaire
# tristesse
# Les réfugiés somaliens coupés de l'aide
# tristesse
# Microsoft minimise le piratage de la reconnaissance vocale de Vista
# joie
# Prochaine île branchée: Sainte-Lucie
# joie
# L'Italie doit tenir un procès contre le Bronx GI en Irak
# colère
# Les parents des garçons sauvés saluent le "miracle"
# joie
# Les Canadiens suivis dans un réseau de pornographie juvénile
# dégoûter
# Teen pirate les sites Web du gouvernement vénézuélien
# surprise
# La Russie envisage de nouveaux ICBM, sous-marins nucléaires
# peur
# Gere encourage les travailleurs du sexe dans la lutte contre le sida
# joie
# Étude: La transpiration chez les hommes provoque la montée des hormones féminines
# surprise
# Une collision sur une route verglacée tue 7 personnes
# tristesse
# Surprise: la Chine réduit son prix de l'essence
# joie
# Ce que le Parrain de l'Âme représentait pour moi
# joie
# Un nouvel orbiteur sur Mars repère le site d'atterrissage de Pathfinder
# joie
# Rassemblement de masse du Venezuela
# colère
# Glamour - et 'Borat' - aux Golden Globes
# joie
# Des responsables du terrorisme voient les chefs d'Al-Qaïda reprendre le pouvoir
# peur
# Ivrea journal: Dans une ville italienne, une leçon d'instruction civique donnée par les voisins
# surprise
# Les terres sunnites irakiennes montrent une nouvelle promesse de pétrole et de gaz
# joie
# La princesse et héritière de Franz Ferdinand se bat pour abroger une loi et gagner un château
# joie
# Une star de cinéma à Kampala, évoquant Aminos Ghost
# peur
# Des militants attaquent une base américaine en Irak
# peur
# L'Afrique du Nord craint comme lieu de terreur pour le terrorisme
# peur
# L'Iran dit que les sunnites, utilisant le Pakistan comme base, planifient un attentat fatal
# peur
# Les anglicans reprochent à la branche américaine de former des unions homosexuelles
# colère
# Des bombes artisanales font 65 morts dans un train indien
# tristesse
# On voit les chefs d'Al-Qaïda reprendre le pouvoir
# peur
# Chavez menace d'emprisonner les contrevenants au contrôle des prix
# colère
# Bush déclare que le rôle des armes de l'Iran en Irak est certain
# peur
# Accord sur la Corée du Nord est annoncé
# joie
# Les États-Unis disent qu'un puissant religieux irakien vit en Iran
# peur
# Le plan de Bagdad est un succès, déclare le Premier ministre irakien à Bush
# joie
# Les terres sunnites irakiennes montrent une nouvelle promesse de pétrole et de gaz
# joie
# Différend concernant un religieux irakien qui se serait rendu en Iran
# colère
# La planification est visible dans les attaques irakiennes contre les États-Unis d'Amérique
# peur
# Dans le monde des médicaments salvateurs, une épidémie croissante de faux médicaments
# tristesse
# Basics: un mammifère en hiver avec son propre four
# surprise
# Livres sur la science: Les problèmes de modélisation de la nature, avec ses tendances naturelles indisciplinées
# surprise
# Croire les Ecritures mais respecter les règles de la science
# surprise
# Une voix familière et presciente, portée à la vie
# joie
# Constatations: 25 millions de dollars pour un plan de sauvegarde du climat
# surprise
# Appelons cela un hasard: une pièce manquante de la tente de guerre de Washington est retrouvée
# joie
# Volonté Libre: maintenant vous l'avez, maintenant vous ne le faites pas
# surprise
# Les archéologues découvrent des signes d'utilisation précoce des outils par les chimpanzés
# surprise
# Magie à Harvard: les physiciens bougent la lumière
# surprise
# Le sommet - une gifle au visage des Palestiniens
# dégoûter
# Moscou: les contacts israélo-palestiniens sont la clé de la paix au Proche-Orient
# joie
# Edns du sommet du Moyen-Orient avec peu de progrès
# tristesse
# L'Inde condamne "un acte de sabotage"
# peur
# Des négociations de paix entre le Pakistan et l'Inde sont prévues malgré les attentats à la bombe
# joie
# Les Tchèques et les Polonais avertis par un missile
# peur
# La Russie met en garde les Etats-Unis contre les bases de missiles en Europe de l'Est
# peur
# Cheney commence sa visite au Japon et en Australie
# joie
# Chine: Cheney renforce l'alliance trilatérale
# joie
# Des insurgés irakiens attaquent une base américaine
# peur
# Les soldats américains meurent au jour de la violence
# tristesse
# Un attentat-suicide irakien tue deux soldats américains alors que des militants luttent pour la purge
# tristesse
# L'Iran renie les paiements nucléaires à la Russie
# peur
# Un haut responsable colombien démissionne
# tristesse
# Le ministre des finances colombien démissionne après l'arrestation de proches par des membres de sa milice
# tristesse
# Le ministre des Affaires étrangères de Colombie quitte le scandale
# dégoûter
# La Nouvelle-Zélande a peu de chances d'autoriser un baleinier japonais estropié
# tristesse
# Un baleinier japonais endommagé pourrait reprendre la chasse au large de l'Antarctique
# tristesse
# Le navire baleinier japonais n'accepte pas l'aide
# dégoûter
# L'Iran, haut représentant de l'Iran, se rend à Vienne pour des pourparlers sur le nucléaire
# joie
# Les victimes d'Air India attendent toujours que justice soit rendue
# tristesse
# Cas d'attentat à la bombe de Kanishka: le juge d'enquête menace de quitter le poste
# dégoûter
# Un juge menace de fermer l'enquête sur Air India
# colère
# Royal sauve les espoirs présidentiels avec une performance remarquable
# joie
# Royal veut relancer l'offre française
# joie
# La zone de confort Sarkozy offre une opportunité royale
# joie
# Hicks en première ligne pour le procès, dit Bush
# peur
# L'Australie demande à Bush d'accélérer le procès de Guantanamo
# surprise
# Howard presse Bush sur un suspect terroriste
# peur
# La France met fin à l'alerte toxique à l'ambassade du Canada à Paris
# peur
# La police parisienne enquête sur un colis à l'ambassade du Canada
# peur
# Fausse alerte à l'ambassade du Canada à Paris
# peur
# Les forces afghanes regagnent une ville envahie par les talibans
# joie
# Les talibans s'emparent d'un district rural dans le sud-ouest du pays
# peur
# La guerre du pavot en Afghanistan aliène les agriculteurs
# tristesse
# La Corée du Nord honorera-t-elle son engagement cette fois-ci?
# joie
# Kim Jong-il interdit les voitures japonaises en Corée du Nord
# surprise
# Iran vs Corée du Nord: tous les ennemis ne sont pas égaux
# colère
# Un archevêque catholique décrit les espoirs d'une fusion anglicane
# joie
# Les églises anglicanes et catholiques pourraient fusionner
# joie
# Un hélicoptère américain tue 8 soldats en Afghanistan
# tristesse
# Huit soldats américains tués dans un accident d'hélicoptère à Zaboul
# tristesse
# Arroyo salue l'adoption du projet de loi antiterroriste
# joie
# La Chambre adopte une mesure antiterroriste à Manille
# joie
# L'empire des transports de Livingstone pourrait s'étendre
# joie
# Selon le maire, Londres est à la pointe de la réduction de la congestion routière
# joie
# Une manifestation salue la poussée de la taxe de congestion vers l'ouest
# colère
# La Thaïlande attaque trois personnes et en blesse 70
# tristesse
# Le gouvernement thaïlandais s'efforce d'assouplir ses relations avec le sud
# joie
# Selon les attentats, les rebelles musulmans ne négocieront pas
# peur
# Les racines de l'autisme plus complexes que prévu
# surprise
# La plus grande étude jamais réalisée sur l'autisme identifie deux coupables génétiques
# surprise
# La percée canadienne donne de l'espoir à l'autisme
# joie
# Attention aux agents pathogènes du beurre de cacahuète
# peur
# Les experts offrent des conseils sur la salmonelle
# joie
# Les experts publient de nouvelles directives sur les maladies cardiaques pour les femmes
# joie
# Pour les femmes, l'aspirine par jour pourrait éviter les accidents
# joie
# Un taux de cholestérol élevé augmente le risque d'accident vasculaire cérébral chez les femmes en bonne santé
# peur
# Des poitrines de poulet cuites rejoignent les rappels d'aliments contaminés
# peur
# Poitrines de poulet prêtes à manger rappelées en raison d'une suspicion de listeria
# peur
# Lamelles de poulet entièrement cuites rappelées
# surprise
# Committee debates cancer vaccine plan
# surprise
# Arrêtez le cancer d'un coup
# joie
# 1 million d'oiseaux à vacciner contre la grippe aviaire près de Moscou
# joie
# Des milliers de personnes testées après l'éclosion de H5N1 en Russie
# peur
# L'épidémie de grippe aviaire russe est une "souche asiatique" mortelle
# peur
# Bernard Matthews va licencier jusqu'à 500 travailleurs
# tristesse
# Matthews licencie 130 travailleurs de dinde
# tristesse
# Réouverture du virus de la grippe aviaire ignore les risques - Poultryman
# peur
# Au revoir à la petite enfance
# tristesse
# Médias cités pour avoir montré des filles comme objets sexuels
# colère
# La sexualisation nuit aux jeunes filles
# colère
# Un coup dans le bras
# peur
# Des milliers de personnes font la queue pour se faire vacciner contre la grippe
# peur
# Comté de King offrant des vaccins gratuits contre la grippe
# joie
# Bush promet une coopération dans le domaine de la santé
# joie
# La santé est de nouveau au centre des préoccupations de la course 2008
# joie
# Les propriétaires de petites entreprises trouvent le régime de santé Bush attrayant
# joie
# Les pédiatres disent qu'il faut plus de sang de cordon maintenant
# peur
# Que ce soit pour sauver le sang de cordon peut être un casse-tête pour les parents
# surprise
# L'implant rétinien aide les aveugles à revoir
# joie
# L'Indonésie "ne partagera pas" les échantillons de grippe
# surprise
# Santé Canada émet un avis sur le thon en conserve
# peur
# Lien entre le cholestérol et le diabète
# tristesse
# Les cellules de porc espèrent guérir le diabète
# surprise
# Un cœur malade allume un gène fœtal
# surprise
# Le mécanisme fœtal aide à l'insuffisance cardiaque
# surprise
# Césariennes planifiées non sans risque, prévient le groupe
# peur
# Les scientifiques vantent les bienfaits du cacao
# joie
# Nourrir son cerveau: les nouveaux avantages du chocolat
# joie
# Certains cacao peuvent améliorer le flux sanguin cérébral
# joie
# L'avocat de Papon, collaborateur décédé de l'ère nazie, s'engage à l'enterrer
# colère
# Le cacao pourrait être un antidote aux maladies liées à l'âge, selon une nouvelle étude
# joie
# La Chine dément les rumeurs d'excuses nord-coréennes
# surprise
# L'opposition hongroise appelle au vote après l'escalade de la violence
# colère
# AU regrets Sudan's expulsion of UN envoy
# tristesse
# Les officiels de Bush: pas de grand pas en Irak
# peur
# L'adversaire est mis sur la sellette pour des remarques à propos de Clinton
# surprise
# Le comité d'éthique de la Chambre s'entretient avec un assistant de Hastert
# joie
# BellSouth dit que le bénéfice augmente de 30% sur le bénéfice courant
# joie
# Le patron d'Enron condamné à 24 ans de prison
# tristesse
# Sony s'excuse pour le rappel de sa batterie
# joie
# Google dévoile un moteur de recherche à faire soi-même
# joie
# Firefox 2.0 frappe le Web
# joie
# Oracle World s'ouvre avec Dell dévoilant les ordinateurs équipés d'AMD
# joie
# Le QB Hasselbeck des Seahawks sort de 2 à 4 semaines
# tristesse
# Le marathonien libéré de l'hôpital
# joie
# Un chasseur accusé de coups de couteau demande à vivre en dehors de l'état
# colère
# Allmendinger rejoint l'équipe Toyota en NASCAR
# joie
# Essayer d'évaluer les dégâts à Cleveland
# tristesse
# La botte de Bryant pourrait avoir sauvé la saison de Bucs
# joie
# Cette semaine en course automobile du 27 au 29 octobre
# joie
# Violation de Merriman étourdit son ancien coéquipier
# surprise
# Bruce s'émerveille
# colère
# Roethlisberger des Steelers a une commotion cérébrale
# tristesse
# Arthurs contrarie Robredo au premier tour de l'Open de Saint-Pétersbourg
# surprise
# Mbeki: La planification de la coupe du monde de football 2010 sur les rails
# joie
# Un essai clinique à Everton
# joie
# MS ajoute Office 2007 au programme de coupon Vista
# joie
# Une recherche ne convient pas à tous
# surprise
# Le secret obscur d'Apple? La réclamation de 39%
# surprise
# Le mauvais temps annule la descente masculine
# tristesse
# Des millions de dollars pour les fondateurs de YouTube
# joie
# Le marché de Londres est un paradis pour le shopping et la restauration
# joie
# La star 'Jackass' épouse un ami d'enfance Les secrets que révèlent les gens
# joie
# Audio Slide Show: Une histoire d'amour de 61 ans
# joie
# Microsoft va sortir un téléphone de nouvelle génération
# joie
# Roddick de Body Shop a l'hépatite C
# tristesse
# Une adolescente prétendument armée par sa mère se transforme en
# peur
# Oxfam: il faut agir pour le Tchad
# joie
# La violence continue sur le site sacré contesté
# tristesse
# La tempête laisse derrière elle de gros problèmes de voyage
# tristesse
# Trois soldats américains tués dans une cache d'armes de chasse
# tristesse
# Les "amis" de la Chine mettent en avant les libertés du Web
# joie
# OTAN: la paix en Afghanistan «d'ici 2009»
# joie
# Les aurores boréales de l'Alaska captivent les Japonais
# joie
# Smith ne peut être enterré avant d'avoir entendu
# tristesse
# Spacewalker établit un nouveau record américain
# joie
# Fortune: l'Inde la superpuissance? Repensez
# surprise
# Kerry dénonce 'l'escalade d'une guerre égarée'
# colère
# Anna Nicole demandeur: un prince d'un gars?
# surprise
# 'Ronnie' et Eto'o s'embrassent et se maquillent
# joie
# Meilleur du Salon de l'auto de Chicago
# joie
# 'Grey's', '' Betty, '' Scrubs 'sont stimulés
# joie
# Des boues massives piègent des dizaines de familles
# tristesse
# Le blogueur Edwards quitte le poste de martyr journalistique
# surprise
# Une ville remplit un gymnase pour faire le deuil de 10 personnes tuées dans un incendie
# tristesse
# L'Espagne devance Nadal
# joie
# La BCE maintient ses taux à 3,5%
# joie
# L'Iran rejette les affirmations américaines de fourniture d'armes en Irak
# peur
# Jakarta commence la désinfection
# joie
# Rowling 'le cœur brisé', '' euphorique '' à l'extrémité 'Potter'
# tristesse
# Apple intensifie les attaques Mac sur Vista
# dégoûter
# La peur empêche le don de moelle noire
# peur
# Un Texan aurait rejoint le complot rebelle somalien
# colère
# Les États-Unis autorisent 7 000 réfugiés irakiens
# joie
# Japon: terroristes de militants de la chasse à la baleine
# peur
# 'Hannibal' mord le grand
# surprise
# Des femmes protestent contre la démolition du Pakistan
# colère
# Nouvelles de la Wii pour les joueurs
# joie
# Les démocrates vont au-delà du vote symbolique sur l'Irak
# joie
# Le Portugal votera sur les lois sur l'avortement
# surprise
# La frustration augmente alors que les pourparlers sur le nucléaire en Corée du Nord prennent fin
# peur
# Dents de cheval donnent des détails de l'ancien grand froid
# surprise
# Scam attire les victimes avec une offre gratuite pour les chiots
# surprise
# Deux Corées pour reprendre les pourparlers
# joie
# Mickelson force motrice chez les maîtres
# joie
# L'Angleterre opte pour Bopara plutôt que pour Loye
# joie
# Créez votre propre 'Thrillville' pour une course folle
# joie
# Le blogueur de la campagne d'Edwards s'arrête au milieu d'une controverse catholique
# surprise
# Juge: conserve le corps d'Anna Nicole
# tristesse
# Les dauphins et les otaries pourraient bientôt se présenter au service
# joie
# La bataille de Nasdaq-LSE arrive à échéance
# peur
# Un plaidoyer personnel pour un plan de vaccination contre le VPH
# joie
# Les États-Unis ouvrent la porte aux réfugiés irakiens
# joie
# Un avion suisse s'écrase à l'aéroport de Moscou
# tristesse
# Étude: la sieste pourrait aider le cœur
# joie
# Hausse des ventes sur MySpace
# joie
# Le géant des télécommunications supprime 12 500 emplois
# tristesse
# Air France KLM profit rises
# joie
# Le parlement ougandais vote pour l'envoi de troupes en Somalie
# peur
# Le roi et la reine règnent aux prix du cinéma britannique
# joie
# Murphys règle box-office avec 'Norbit'
# joie
# Des milliers de personnes se rassemblent au Liban
# peur
# La quête de mission de Yahoo
# joie
# La région devrait recevoir 3 à 5 pouces de neige aujourd'hui
# joie
# Miss Brésil gagne le concours de procès
# joie
# La neige fait des ravages dans l'Est et le Midwest
# tristesse
# Les secrets que les gens révèlent
# surprise
# La recherche soutient la marijuana médicinale
# surprise
# Coup d'envoi pour tous les matchs de football pour les amputés d'Afrique
# joie
# Groupe: Vidéo montre chopper descendre
# tristesse
# Vente de Chrysler possible
# joie
# La Russie condamne les actes terroristes perpétrés à bord d'autobus à l'extérieur de Beyrouth
# tristesse
# La technologie pourrait sauver les dauphins indiens
# joie
# Le superjumbo Airbus A380 prend son envol
# joie
# Les siestes sont parfaits pour les gars
# joie
# Record d'astronaute féminin
# joie
# Des fourneaux de maïs surgissent dans les foyers américains
# surprise
# L'Irak ferme ses frontières avec la Syrie et l'Iran
# tristesse
# La fin troublante de 'The Departed'
# tristesse
# Une banque vietnamienne envisage d'introduire en bourse
# joie
# Les Scion de Toyota dans Second Life
# surprise
# Obama courra en 2008
# joie
# 'Cagney & Lacey' arrive enfin en DVD
# joie
# Merkel: Stop à l'Iran
# peur
# Salt Lake City centre de tir était adolescent
# tristesse
# Record d'astronaute féminin
# joie
# Le pétrole détient 58 $
# joie
# Obama annonce sa candidature à la présidence
# joie
# Dites à votre patron: les siestes sont bonnes pour vous
# joie
# La Serbie rejette le plan du Kosovo des Nations Unies
# colère
# Amish discute de fusillades
# tristesse
# Emprisonne-moi, j'ai mangé du chocolat ivoirien
# surprise
# Peut-on faire confiance à la Corée du Nord?
# peur
# Le tourisme à la traîne dans la ville natale de Bush
# tristesse
# L'arrestation de l'astronaute met la NASA à l'épreuve
# surprise
# L'homme a une deuxième chance dans l'espace
# joie
# Allez-y, faites une sieste, dit la science
# surprise
# L'hebdomadaire Nielsen "Lost" retrouvera-t-il son chemin?
# joie
# Les frais de bagages de British Airways sont source de confusion
# surprise
# Indonésien meurt de grippe aviaire
# tristesse
# Saint-Louis sur le point de se divertir
# joie
# La ville de New York peut interdire les iPod en traversant une rue
# surprise
# Un garçon qui aurait été obligé de tuer par sa mère abandonne
# tristesse
# Loups gris hors liste en voie de disparition
# joie
# La sécurité surexcitée de Vista sera testée
# joie
# La police britannique critiquée pour son raid terroriste
# peur
# Les habitants de Mogadiscio fuient les explosions
# peur
# Une bombe tue 18 personnes dans un bus militaire en Iran
# tristesse
# 'WarioWare', la Wii convient parfaitement
# joie
# Les États-Unis en désaccord avec l'aide du clerc
# peur
# Une mère irakienne désespérée compte sur l'aide de la milice
# tristesse
# Détails complets du rapport de l'UE sur l'Iran
# surprise
# Chanteur sur Cowell: content qu'il soit méchant
# joie
# Jones affronte les rencontres européennes
# tristesse
# Beckham aide le Real à s'imposer
# joie
# Guinée: Les bureaux du plan ferment leurs portes alors que le pays déclare l'urgence
# peur
# L'économie japonaise se développe
# joie
# Les Casques bleus des Nations Unies attaquent un bidonville en Haïti
# joie
# Début des travaux sur le coffre à graines arctique
# joie
# Le réseautage social devient mobile
# joie
# Les esthéticiennes coupent, courbent et offrent des informations sur la prévention des accidents vasculaires
# joie
# Une étude conclut que la Siesta réduit le risque de décès par maladie cardiaque
# surprise
# Thomas Cook fusionne avec MyTravel
# joie
# Nap votre chemin vers une carrière réussie
# joie
# Village enseveli sous 100 pouces de neige
# tristesse
# Oprah annonce un nouveau choix de club de lecture
# joie
# La science de l'amour ... et de la luxure
# joie
# Northeaster annule les vols et ferme les écoles
# tristesse
# Faire une sieste peut être bon pour votre cœur
# joie
# Ryan O'Neal, petite amie de son fils blessé
# tristesse
# Le massacre de la Saint-Valentin chez Chrysler
# tristesse
# Procès des attentats de Madrid
# peur
# La lutte commence contre le vaccin anti-HPV
# dégoûter
# Les voitures génèrent des gains européens
# joie
# Le partenaire de James Brown peut avoir ses affaires
# joie
# Auto show annulé
# tristesse
# Le fabricant de luxe britannique Burberry: «Fabriqué en Chine»?
# surprise
# Les siestes en cours de travail pourraient réduire le risque cardiaque
# joie
# La Floride, n ° 1, survit à Rupp Arena et enregistre 16 victoires consécutives
# joie
# J.K. Rowling marque la fin de "Potter"
# tristesse
# Gronholm prend les devants
# joie
# Howard critique Obama de la politique irakienne
# colère
# Manille fait allusion à l'approbation d'une rançon
# tristesse
# Champion Murray trop bon pour Kim
# joie
# G7: le yen patine, le yuan choisi
# tristesse
# Gunman 'était un survivant de Srebrenica'
# surprise
# Réduire le fouillis pour faire avancer les choses
# joie
# Mère: Lohan se débrouille bien en cure de désintoxication
# joie
# Qui va gagner aux Grammys?
# joie
# La défense de Libby bouleverse le juge et repose
# surprise
# Les anneaux de rupture trouvent de nouvelles maisons
# tristesse
# Gronholm en avance alors que Solberg s'écrase
# joie
# 'Norbit' un gaspillage de Murphy
# tristesse
# Début difficile pour l'aéroport de Bangkok
# surprise
# 12 morts dans des attentats en minibus libanais
# tristesse
# L'armée russe est victime de torture sexuelle
# dégoûter
# Les méga-marsupiaux parcouraient autrefois l'Australie
# surprise
# Le TiVo secret de Rupert Murdoch
# surprise
# UPDATE 1-Plane s'écrase à l'aéroport de Moscou, pas de passagers
# tristesse
# La vaccination contre le VPH suscite un débat houleux en Amérique
# surprise
# Court TV: un assassin accusé raconte au jury une histoire d'amour
# surprise
# Site Web sur la dénonciation exposé
# surprise
# Commencer tard, retraite riche
# joie
# Le Premier ministre somalien promet de traduire les islamistes en justice
# colère
# Les échangistes plus communs que la plupart pensent
# surprise
# Anna Nicole Smith: les internautes pleurent dans le cyberespace
# tristesse
# L'antibiotique Ketek plus dangereux que prévu
# peur
# Il est temps de réserver votre croisière
# joie
# Blazing Angels pour la PS3 ne parvient pas à monter en flèche
# tristesse
# Corée du Nord: demande de décrochage
# tristesse
# Cartoon Network démissionne
# tristesse
# La Malaisie courtise les touristes
# joie
# La maison d'Anna Nicole Smith aux Bahamas saisie
# tristesse
# Andromède impliqué dans une collision galactique
# surprise
# Le Rwanda envisage une limite de 3 enfants pour les familles
# joie
# Wilkinson établit un record en victoire
# joie
# Les ingénieurs de l'armée disent que le barrage est sécurisé
# joie
# France: des suspects d'Al-Qaïda arrêtés
# peur
# Un homme armé de l'Utah a survécu à Srebrenica
# joie
# Créer un album entier en un mois?
# surprise
# L'Inde va tester un nouveau missile nucléaire
# peur
# G7 vers la Chine: facilité de prise en charge des taux de change
# surprise
# Hatton rend le titre IBF à nouveau
# joie
# Bernanke: L'économie est saine, mais ...
# peur
# Mickelson et Sutherland en tête du classement
# joie
# La sieste est bonne pour votre cœur, selon une étude
# joie
# Princesse Masako auteur: aucun regret
# surprise
# Les étudiants utilisent IM-Lingo dans des essais
# surprise
# La Malaisie lance une campagne touristique
# joie
# Étude: Le fossé Internet en Afrique s'élargit
# tristesse
# Le chaos du voyage alors que la neige frappe le Royaume-Uni
# peur
# Paula Abdul: 'Je n'ai jamais été ivre'
# surprise
# Épidémie de salmonelle imputable au beurre d'arachide
# peur
# Poutine: la force américaine favorise les ambitions nucléaires
# peur
# Des détecteurs nucléaires sonneront à New York, selon un responsable
# peur
# Un double attentat en bus tue trois personnes au Liban
# tristesse
# Davydenko dehors comme des graines dispersées
# surprise
# Obama: je me présente à la présidence
# joie
# Paterson bat l'Ecosse vers la victoire
# joie
# Les Afro-Américains sont des donneurs d'organes de nos jours, mais qu'en est-il de la moelle osseuse?
# surprise
# Étude: Les siestes au travail pourraient aider le cœur
# joie
# La capitale guinéenne est en grande partie calme sous le couvre-feu
# peur
# Les patrons qui dorment à l'idée de laisser les travailleurs faire la sieste
# surprise
# La conviction porno de l'enseignant suscite un débat technologique
# dégoûter
# Singapour prend soin de sa promenade au bord de l'eau
# joie
# Le Rwanda envisage une limite de trois enfants
# surprise
# Samsung règle le litige sur la fixation des prix
# joie
# Le religieux radical al-Sadr en Iran, insiste sur le fait que
# peur
# Rapports: Harvard devrait nommer sa première présidente
# joie
# L'Irak dévoile de nouveaux plans de sécurité
# surprise
# L'université offre son soutien à l'école de la Nouvelle-Orléans
# joie
# Une tempête provoque des routes glissantes et glacées
# peur
# Un incendie en Corée du Sud tue 10 étrangers
# tristesse
# Des amants préhistoriques retrouvés enfermés dans une éternelle étreinte
# surprise
# Graphiques: Votre ville est-elle maigre ou léthargique?
# surprise
# Un dirigeant du Pérou interrogé dans une enquête sur un massacre
# tristesse
# Commandant américain: l'Irak n'est pas sans espoir
# joie
# Le Premier ministre australien aux côtés d'Obama
# joie
# Mardi Gras rebondit pour la Nouvelle-Orléans?
# joie
# Siestas peut réduire le risque de maladie cardiaque
# joie
# Un plongeur de l'Oregon pris pour un rongeur, abattu au visage
# tristesse
# Petraeus prend le commandement en Irak
# peur
# 6 morts après le tir de Utah Mall
# tristesse
# Les requins tuent quatre personnes en une année "terne"
# tristesse
# Record-fracassant jour sur Wall St.
# joie
# Un comédien dit que le gouvernement réduit au silence les critiques
# tristesse
# Les rockers sont les grands gagnants des Brit Awards
# joie
# Un dirigeant d'école de samba tué avant le carnaval de Rio
# tristesse
# Taiwan's 'Mr. Clean 'inculpé, démissionne
# tristesse
# Une femme se bat pour garder son chauffeur ivre en prison
# colère
# Un groupe d'Al-Qaïda appelle à des attaques sur le pétrole américain
# peur
# Cousin: Gunman était un survivant de Srebrenica
# tristesse
# Le Turkménistan vote pour le président
# joie
# Voici quelques conseils à prendre à coeur ...
# surprise
# 10 avantages fiscaux à ne pas manquer
# joie
# La police casse les manifestations au Kosovo
# colère
# Messi fait son retour à Barcelone
# joie
# Saut signalé dans des décès accidentels dus à une surdose de drogue
# tristesse
# Catane punie pour la violence de ses fans
# tristesse
# Isinbayeva établit un 20e record du monde
# joie
# Les législateurs sifflent à la FDA pour surveiller la sécurité des médicaments
# colère
# Les siestes régulières rendent les cœurs sains
# joie
# La glace arrête les chariots à froid
# tristesse
# U. le tireur 'était un survivant de Srebrenica'
# surprise
# Nourriture pour bébé périmée trouvée sur les étagères
# dégoûter
# Les chauffeurs de remorques accusés d'avoir volé des voitures
# dégoûter
# Bush: Il est temps que le Congrès soutienne son plan énergétique
# joie
# Soldats britanniques libérés des abus de l'Irak
# joie
# La FDA révise les avertissements sur l'étiquette de l'antibiotique Ketek
# joie
# Toshiba Portege R400
# joie
# L'Afrique du Sud pleure Adelaide Tambo
# tristesse
# Les évacués peuvent rentrer chez eux après l'explosion d'une plante
# joie
# Le corps d'Anna Nicole Smith est dans les limbes juridiques
# tristesse
# Une ancienne prof pose pour Playboy
# surprise
# La France rejette les enquêteurs rwandais
# colère
# Une sieste par jour peut éloigner le cardiologue
# surprise
# Higley et Gonzalez en tête en Malaisie
# joie
# Les Grammys prêts à nommer les gagnants
# joie
# La livre ne laissera pas tomber l'affaire Armstrong
# colère
# La police réunie entame une tournée mondiale en mai
# joie
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-e9ab01a15238> in <module>
#      11     try:
#      12             # translate the 'text' column
# ---> 13             text_translated = translator.translate(row[0], dest='fr')
#      14             print(text_translated.text)
#      15             sentiment_translated = translator.translate(row[1], dest='fr')
#
# ~\Anaconda3\lib\site-packages\googletrans\client.py in translate(self, text, dest, src)
#     170
#     171         origin = text
# --> 172         data = self._translate(text, dest, src)
#     173
#     174         # this code will be updated when the format is changed.
#
# ~\Anaconda3\lib\site-packages\googletrans\client.py in _translate(self, text, dest, src)
#      73             text = text.decode('utf-8')
#      74
# ---> 75         token = self.token_acquirer.do(text)
#      76         params = utils.build_params(query=text, src=src, dest=dest,
#      77                                     token=token)
#
# ~\Anaconda3\lib\site-packages\googletrans\gtoken.py in do(self, text)
#     198
#     199     def do(self, text):
# --> 200         self._update()
#     201         tk = self.acquire(text)
#     202         return tk
#
# ~\Anaconda3\lib\site-packages\googletrans\gtoken.py in _update(self)
#      55             return
#      56
# ---> 57         r = self.session.get(self.host)
#      58
#      59         raw_tkk = self.RE_TKK.search(r.text)
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# ~\Anaconda3\lib\site-packages\requests\models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# ~\Anaconda3\lib\site-packages\requests\models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in read_chunked(self, amt, decode_content)
#     592         with self._error_catcher():
#     593             while True:
# --> 594                 self._update_chunk_length()
#     595                 if self.chunk_left == 0:
#     596                     break
#
# ~\Anaconda3\lib\site-packages\urllib3\response.py in _update_chunk_length(self)
#     534         if self.chunk_left is not None:
#     535             return
# --> 536         line = self._fp.fp.readline()
#     537         line = line.split(b';', 1)[0]
#     538         try:
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     275     def recv_into(self, *args, **kwargs):
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#     279             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
df_fr.to_pickle('data/df_FR_News911.p')

# %%
import goslate

import copy
nb = 0
df_fr = pd.DataFrame() 
for index, row in df_en.iterrows():
    # REINITIALIZE THE API
    gs = goslate.Goslate()
    if(nb<101):
        nb = nb +1 
        try:
            # translate the 'text' column
            text_translated = gs.translate(row[0], 'fr')
            print(text_translated)
            newrow['text'] = text_translated
            sentiment_translated = gs.translate(row[1], 'fr')
            newrow['sentiment'] = sentiment_translated
            print(sentiment_translated)
            #print(newrow)
            df_fr.append({'text': text_translated, 'sentiment': sentiment_translated}, ignore_index=True)

        except Exception as e:
            print(str(e))
            continue
    else: break 
print ("I'm out ")
# Out:
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# HTTP Error 503: Service Unavailable
# I'm out

# %%
df_fr
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#     694         See Also
#     695         --------
# --> 696         to_html : Convert DataFrame to HTML.
#     697
#     698         Examples
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border, table_id)
#    2035             Dictionary mapping columns containing datetime types to stata
#    2036             internal format to use when writing the dates. Options are 'tc',
# -> 2037             'td', 'tm', 'tw', 'th', 'tq', 'ty'. Column can be either an integer
#    2038             or a name. Datetime columns that do not have a conversion type
#    2039             specified will be converted to 'tc'. Raises NotImplementedError if
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, classes, notebook, border)
#     751             need_leadsp = dict(zip(fmt_columns, map(is_numeric_dtype, dtypes)))
#     752
# --> 753             def space_format(x, y):
#     754                 if (y not in self.formatters and
#     755                         need_leadsp[x] and not restrict_formatting):
#
# TypeError: __init__() got an unexpected keyword argument 'max_rows'
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_en[911:]
# Out:
#                                                       0         1
# 1411    Turkmen acting leader sworn in as new president       joy
# 1412                   Allen and Okur get All-Star call       joy
# 1413                   Svindal claims are golden double       joy
# 1414  Trolley Square shooting leaves 6 dead, includi...   sadness
# 1415                    Bridge blast stops I-95 traffic      fear
# 1416               Mother, daughter stabbed near school   sadness
# 1417                 Excerpt: Politicians and the press   disgust
# 1418               North Korea gets 'money and respect'       joy
# 1419   Beyonce in a bikini as SI's swimsuit cover model       joy
# 1420                     Loving with all your ... brain  surprise
# 1421    Shoplifters' choice: Police or T-shirt of shame  surprise
# 1422                  Cuban official: Web a 'wild colt'      fear
# 1423                            Slow 'Music and Lyrics'       joy
# 1424       Mexican navy helps in hunt for U.S. engineer       joy
# 1425                  Smith baby may not be pot of gold   sadness
# 1426              Latest updates on world's top stories      fear
# 1427                        Beating leaves teen in coma   sadness
# 1428                     Tiempo Libre has Grammy dreams       joy
# 1429         GPS sneakers locate with press of a button  surprise
# 1430           Embattled Edwards blogger quits campaign   sadness
# 1431  Britons deported from Somalia held under Terro...      fear
# 1432                     Updates on world's top stories      fear
# 1433                   Breast cancer drug promises hope       joy
# 1434         Ancient coin shows Cleopatra was no beauty  surprise
# 1435                  YouTube yields surprising payback  surprise
# 1436                Up to 22 inches of snow in forecast  surprise
# 1437                  Werder make 10-man Ajax pay price       joy
# 1438                  EU condemns 'illegal' CIA flights     anger
# 1439              Report links humans to global warming      fear
# 1440               UN nuclear watchdog slashes Iran aid     anger
# ...                                                 ...       ...
# 1470               Frantic 911 call in Ryan O'Neal case  surprise
# 1471                 Durant's success trumps the Gators       joy
# 1472           Scientist snoops in astronauts' journals   disgust
# 1473                YouTube founders split $650M payout       joy
# 1474               African nation hopes Whoopi can help       joy
# 1475                   United hang on to six-point lead       joy
# 1476                 Lawyer seizes Smith's Bahamas home   sadness
# 1477             Was Prince's super show too revealing?  surprise
# 1478                 Clijsters looks for a long goodbye   sadness
# 1479               Snow's too deep even for snowmobiles  surprise
# 1480              Study: Female seals picky about mates  surprise
# 1481  ROUNDUP: Protests erupt despite "state of sieg...     anger
# 1482            Study: More kids exposed to online porn   disgust
# 1483                   Beyonce new SI bikini cover girl       joy
# 1484    Marijuana helps ease HIV nerve pain, study says  surprise
# 1485                 Serena misses Bangalore tournament   sadness
# 1486        Dryer blamed for fire killing 39 cats, dogs   sadness
# 1487                  Roddick, Murray score in San Jose       joy
# 1488                    Apple trademark dispute settled       joy
# 1489                 U.S. online love brokers eye China   sadness
# 1490               U.S. diverts troops to fight Taliban     anger
# 1491         'House of Cards' actor Ian Richardson dead   sadness
# 1492                 Taliban leader killed in airstrike   sadness
# 1493         Escape to Prague without the summer hordes       joy
# 1494                  Kathmandu: First snow in 63 years  surprise
# 1495                        Nasdaq fails in bid for LSE   sadness
# 1496                      Ex-pastor gets death sentence   sadness
# 1497        Baby born on turnpike after dad misses exit  surprise
# 1498                   Study links chimps and 'hammers'  surprise
# 1499                 UN-Google Earth map climate change       joy
#
# [89 rows x 2 columns]
