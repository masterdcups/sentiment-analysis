# %%
import numpy as np 
import pandas as pd 
pd.set_option('display.max_colwidth', -1)
from time import time
import re
import string
import os
import emoji
from pprint import pprint
import collections

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.set(font_scale=1.3)

import gensim
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
from spellchecker import SpellChecker

import warnings
warnings.filterwarnings('ignore')

np.random.seed(37)

# %%
df_tweet_en = pd.read_pickle('../data/final/NotIot_EN_tweets.p')
df_tweet_en
# Out:
#                                                                                                                                                       Tweet  \
# ID
# 2017-En-20421  Now #India is #afraid of #bad .
# 2017-En-11490  He's seriously so frustrating sometimes! (╯°□°）╯︵ ┻━┻ #ugh #raging
# 2017-En-21004  How in the world did Nicole beat Paul?!?! #terrible #bb18 #BBFinale What was the jury thinking?? 😳😳😳
# 2017-En-11411  Yeah, no. I don' mind tweetin' that twice. #snap #blm #likeThat
# 2017-En-21007  What's the most important thing you need to accomplish today? #onlinemarketing #solopreneur #start up #success
# 2017-En-21331  like srsly somebody help me deal with this social anxiety
# 2017-En-10886  @isthataspider @dhodgs i will fight this guy! Don't insult the lions like that! But seriously they kinda are.Wasted some of the best players
# 2017-En-20965  Don't let fear hold you back from being who you want to be. Use it's power to push you towards your goals. No more fear, just action. #fear
# 2017-En-31134  Good morning.Let's start with a smile!\nLet's enjoy life in a cheerful way!\nDon't worry be happy!
# 2017-En-30182  @R1Breakfast Totes had to re-listen to the endless hilarity that was Tom Odell's 'raaar' this morning 😂😂😂 @grimmers @fionaradio @TinaDaheley
# 2017-En-30336  For a moment I found myself smiling
# 2017-En-21147  I know this is going to be one of those nights where it takes an Act of God to fall asleep.
# 2017-En-41371  the sad moment when u hand in an exam knowing u failed and grieve by eating and sleeping
# 2017-En-10815  I think they may be
# 2017-En-40981  I don't care what shape the blues are in. \nWe owe them a fucking hiding. \nLong overdue on that front.
# 2017-En-10872  Is it me, or is Ding wearing the look of a man who's just found his arch enemy in bed with his missus? #angryman
# 2018-En-03633  I feel like I should be watching #glee, but #glee will just make me cry and I'm trying to remember happy times
# 2017-En-30938  Drawing mini-comics is joyful; folding mini-comics is meditative and relaxing. I think I need to do them for more than just Halloween...
# 2017-En-22068  Side chick's be trying to fuck u like your going to forget about your wife when your done. #terrible
# 2017-En-31604  This meth documentary is exhilarating
# 2017-En-20061  Wish I could convince the rest of my children to go to their fucking preschool and elementary schools with fear of gun violence.
# 2017-En-11428  Or when they hmu on snap, and I'm like.. which one are you. 💀
# 2017-En-40710  The labor of love is not cheap or inexpensive, it's the time spent earning it. #lackadaisical #dreamer
# 2017-En-20146  What an actual nightmare
# 2017-En-10452  The best revenge is to move on, get over it, and continue to succeed. Never give someone the satisfaction of watching you suffer.
# 2017-En-31567  @indermethil True. We were rejoicing the fact that we signed a quality young CB but we need one more at least. @MarcBartra ? mebbe :P
# 2017-En-41223  @KhaleesiofFood @BB_Updates she has stayed off the block almost all season, got out people that were good for her game, but no one seemed
# 2017-En-10238  And she got all angry telling me 'but what would be doing a 40 year old guy looking for a girl like you' and I felt #offended
# 2018-En-02943  Dirty Chai tea with Rumchata hits the spot on this gloomy Tuesday morning. 😊
# 2017-En-20513  @AnneMarieIAm Heard #alarm 1. time in Germany today #youFM, TG finally .. and far far too late. Germany always late w UK artists!!😡😠
# 2017-En-11411  0          0        0         0
# 2017-En-21007  0          0        0         0
# 2017-En-21331  0          0        0         0
# 2017-En-10886  1          0        0         0
# 2017-En-20965  0          0        0         0
# 2017-En-31134  0          0        0         1
# 2017-En-30182  0          0        0         0
# 2017-En-30336  0          0        0         0
# 2017-En-21147  1          0        0         0
# 2017-En-41371  1          1        0         0
# 2017-En-10815  0          0        0         0
# 2017-En-40981  0          0        0         0
# 2017-En-10872  0          0        0         0
# 2018-En-03633  0          1        0         0
# 2017-En-30938  0          0        0         1
# 2017-En-22068  0          1        0         0
# 2017-En-31604  0          0        0         0
# 2017-En-20061  0          1        0         0
# 2017-En-11428  0          0        0         0
# 2017-En-40710  0          1        0         0
# 2017-En-20146  1          0        0         0
# 2017-En-10452  0          0        0         0
# 2017-En-31567  0          0        0         0
# 2017-En-41223  0          0        0         0
# 2017-En-10238  0          0        0         0
# 2018-En-02943  0          0        1         0
# 2017-En-20513  0          0        0         0
# ...           ..         ..       ..        ..
# 2017-En-40268  0          1        0         0
# 2018-En-00835  0          1        0         0
# 2017-En-10126  0          0        0         0
# 2017-En-41009  0          1        0         0
# 2017-En-11071  0          0        0         0
# 2017-En-10917  0          0        0         0
# 2017-En-21420  0          0        0         1
# 2017-En-21318  0          1        0         0
# 2017-En-40697  0          0        0         1
# 2017-En-20940  0          0        0         0
# 2017-En-40393  0          0        0         0
# 2017-En-10427  0          1        0         0
# 2017-En-31236  0          0        0         0
# 2017-En-21708  0          0        0         0
# 2017-En-21298  0          1        0         0
# 2017-En-40527  0          0        0         0
# 2017-En-30605  0          0        0         0
# 2017-En-30958  0          0        0         0
# 2017-En-10363  0          0        0         0
# 2017-En-21044  0          0        0         1
# 2017-En-10741  0          1        0         0
# 2017-En-20003  1          1        0         0
# 2017-En-21279  0          0        1         0
# 2017-En-30198  0          0        0         0
# 2017-En-30358  0          0        0         0
# 2017-En-20510  1          0        0         0
# 2017-En-20779  0          0        0         0
# 2017-En-10491  0          1        0         0
# 2017-En-21099  0          0        1         0
# 2017-En-10346  0          0        0         0
#
# [7724 rows x 12 columns]

# %%
new_df_tweet_en = pd.DataFrame(columns=['text', 'emotion'])
for row in df_tweet_en.itertuples(index=False):
    print(row['Tweet'])
   
new_df_tweet_en
# Out:
# ('2017-En-20421', Tweet           Now #India is #afraid of #bad .
# anger           0
# anticipation    0
# disgust         0
# fear            1
# joy             0
# love            0
# optimism        0
# pessimism       0
# sadness         0
# surprise        0
# trust           0
# Name: 2017-En-20421, dtype: object)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-6ec7976c7946> in <module>
#       4     column_name  = ["anger","anticipation","disgust","fear","joy","love","optimism","pessimism","sadness","surprise","trust"]
#       5     for column in column_name:
# ----> 6         if row[column] == 1:
#       7             new_df_tweet_en.append(row['Tweet'],column)
#       8             continue
#
# TypeError: tuple indices must be integers or slices, not str

# %%
class TextCounts(BaseEstimator, TransformerMixin):
    
    def count_regex(self, pattern, tweet):
        return len(re.findall(pattern, tweet))
    
    def fit(self, X, y=None, **fit_params):
        # fit method is used when specific operations need to be done on the train data, but not on the test data
        return self
    def space_uderscore(self, input_text):
        # By compressing the underscore, the emoji is kept as one word
        #return re.sub(r':([a-z&]+)_([a-z&]+):', r'\1\2', input_text)
        return input_text.replace('_',' ')
    def transform(self, X, **transform_params):
        count_words = X.apply(lambda x: self.count_regex(r'\w+', x)) 
        count_mentions = X.apply(lambda x: self.count_regex(r'@\w+', x))
        count_hashtags = X.apply(lambda x: self.count_regex(r'#\w+', x))
        count_capital_words = X.apply(lambda x: self.count_regex(r'\b[A-Z]{2,}\b', x))
        count_excl_quest_marks = X.apply(lambda x: self.count_regex(r'!|\?', x))
        count_urls = X.apply(lambda x: self.count_regex(r'http.?://[^\s]+[\s]?', x))
        # We will replace the emoji symbols with a description, which makes using a regex for counting easier
        # Moreover, it will result in having more words in the tweet
        count_emojis = X.apply(self.space_uderscore).apply(lambda x: emoji.demojize(x)).apply(lambda x: self.count_regex(r':[a-z_&]+:', x))
        
        df = pd.DataFrame({'count_words': count_words
                           , 'count_mentions': count_mentions
                           , 'count_hashtags': count_hashtags
                           , 'count_capital_words': count_capital_words
                           , 'count_excl_quest_marks': count_excl_quest_marks
                           , 'count_urls': count_urls
                           , 'count_emojis': count_emojis
                          })
        
        return df

# %%
textcount = TextCounts()
df_eda = textcount.fit_transform(df_tweet_en.text)
# Add airline_sentiment to df_eda
df_eda['sentiment'] = df_tweet_en.sentiment
df_eda['origin_text'] = df_tweet_en.text
df_eda['likes'] =  df_tweet_en.likes
df_eda['retweets'] =  df_tweet_en.retweets

# %%
def show_dist(df, col):
    print('Descriptive stats for {}'.format(col))
    print('-'*(len(col)+22))
    print(df.groupby('sentiment')[col].describe())
    bins = np.arange(df[col].min(), df[col].max() + 1)
    g = sns.FacetGrid(df, col='sentiment', size=5, hue='sentiment', palette="PuBuGn_d")
    g = g.map(sns.distplot, col, kde=False, norm_hist=True, bins=bins)
    plt.show()

# %%
show_dist(df_eda, 'count_words')
# Out:
# Descriptive stats for count_words
# ---------------------------------
#              count      mean        std  min   25%   50%   75%     max
# sentiment
# negative   20000.0  18.04060  10.465712  2.0  14.0  18.0  21.0  1002.0
# neutral    20000.0  18.70125  26.951032  4.0  15.0  18.0  21.0  2755.0
# positive   20000.0  18.18690  13.958625  2.0  14.0  18.0  22.0  1233.0

# %%
show_dist(df_eda, 'count_mentions')
# Out:
# Descriptive stats for count_mentions
# ------------------------------------
#              count     mean       std  min  25%  50%  75%   max
# sentiment
# negative   20000.0  0.34440  0.692541  0.0  0.0  0.0  1.0  20.0
# neutral    20000.0  0.40075  0.785481  0.0  0.0  0.0  1.0  28.0
# positive   20000.0  0.62965  1.007294  0.0  0.0  0.0  1.0  19.0

# %%
show_dist(df_eda, 'count_hashtags')
# Out:
# Descriptive stats for count_hashtags
# ------------------------------------
#              count     mean       std  min  25%  50%  75%   max
# sentiment
# negative   20000.0  1.06350  1.394333  0.0  0.0  1.0  2.0  49.0
# neutral    20000.0  1.97840  2.134470  0.0  1.0  2.0  3.0  90.0
# positive   20000.0  2.04785  1.593734  0.0  1.0  2.0  3.0  73.0

# %%
show_dist(df_eda, 'count_capital_words')
# Out:
# Descriptive stats for count_capital_words
# -----------------------------------------
#              count     mean       std  min  25%  50%  75%   max
# sentiment
# negative   20000.0  0.30060  0.882994  0.0  0.0  0.0  0.0  23.0
# neutral    20000.0  0.45815  0.935464  0.0  0.0  0.0  1.0  32.0
# positive   20000.0  0.33760  0.835441  0.0  0.0  0.0  0.0  22.0

# %%
show_dist(df_eda, 'count_excl_quest_marks')
# Out:
# Descriptive stats for count_excl_quest_marks
# --------------------------------------------
#              count     mean       std  min  25%  50%  75%   max
# sentiment
# negative   20000.0  0.18910  0.495029  0.0  0.0  0.0  0.0  14.0
# neutral    20000.0  0.22040  0.573969  0.0  0.0  0.0  0.0  23.0
# positive   20000.0  0.39705  0.706559  0.0  0.0  0.0  1.0  18.0

# %%
show_dist(df_eda, 'count_urls')
# Out:
# Descriptive stats for count_urls
# --------------------------------
#              count     mean       std  min  25%  50%  75%    max
# sentiment
# negative   20000.0  1.05395  0.769655  0.0  1.0  1.0  1.0  48.0
# neutral    20000.0  1.17985  1.541338  0.0  1.0  1.0  1.0  147.0
# positive   20000.0  1.02795  0.898114  0.0  1.0  1.0  1.0  61.0

# %%
show_dist(df_eda, 'count_emojis')
# Out:
# Descriptive stats for count_emojis
# ----------------------------------
#              count     mean       std  min  25%  50%  75%   max
# sentiment
# negative   20000.0  0.00585  0.102060  0.0  0.0  0.0  0.0  6.0
# neutral    20000.0  0.01230  0.234630  0.0  0.0  0.0  0.0  17.0
# positive   20000.0  0.01295  0.269046  0.0  0.0  0.0  0.0  21.0

# %%
class CleanText(BaseEstimator, TransformerMixin):
    
    def remove_mentions(self, input_text):
        return re.sub(r'@\w+', '', input_text)
    
    #def remove_hashtags(self, input_text):
        #return re.sub(r'#\w+', '', input_text)    
    
    def remove_urls(self, input_text):
        return re.sub(r'http.?://[^\s]+[\s]?', '', input_text)
    
    def emoji_oneword(self, input_text):
        # By compressing the underscore, the emoji is kept as one word
        #return re.sub(r':([a-z&]+)_([a-z&]+):', r'\1\2', input_text)
        return input_text.replace('_','')
    
    def remove_punctuation(self, input_text):
        # Make translation table
        punct = string.punctuation
        trantab = str.maketrans(punct, len(punct)*' ')  # Every punctuation symbol will be replaced by a space
        return input_text.translate(trantab)

    def remove_digits(self, input_text):
        return re.sub('\d+', '', input_text)
    
    def to_lower(self, input_text):
        return input_text.lower()
    
    def replace_acronyms(self, input_text):
        acronyms_dic = {"B4" : "before","BFN":"bye for now","BGD" : "background","BH":"blockhead","BR":"best regards",
                        "BTW" : "by the way","OMG":"oh my god"}
        acronyms_pattern = re.compile(r'\b(' + '|'.join(acronyms_dic.keys()) + r')\b')
        return acronyms_pattern.sub(lambda x: acronyms_dic[x.group()], input_text)
        
    def stopwords_spell(self, input_text):
        stopwords_list = stopwords.words('english')
        # Some words which might indicate a certain sentiment are kept via a whitelist
        whitelist = ["n't", "not", "no"]
        blacklist = ["via","rt"]
        words = input_text.split() 
        clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and (word not in blacklist) and len(word) > 1] 
        #correct words
        #spell = SpellChecker()
        correct_words = [word for word in clean_words]
        return " ".join(correct_words) 
    
    def stemming(self, input_text):
        porter = PorterStemmer()
        words = input_text.split() 
        stemmed_words = [porter.stem(word) for word in words]
        return " ".join(stemmed_words)
    
    def fit(self, X, y=None, **fit_params):
        return self
    
    def transform(self, X, **transform_params):
        clean_X = X.apply(self.remove_mentions).apply(self.remove_urls).apply(self.emoji_oneword).apply(self.replace_acronyms).apply(self.remove_punctuation).apply(self.remove_digits).apply(self.to_lower).apply(self.stopwords_spell).apply(self.stemming)
        return clean_X

# %%
cleantext = CleanText()
sr_clean = cleantext.fit_transform(df_tweet_en.text)
sr_clean.sample(5)
# Out:
# 5330961    not love iot spi custom arriv regist privaci secur
# 3249032    internet thing world forum showcas smart citi technolog kuwait time
# 318612     arm studi internet thing real act
# 994985     new oper system connect internetofth iot os
# 448867     internet thing
# Name: text, dtype: object

# %%
cv = CountVectorizer()
bow = cv.fit_transform(sr_clean)
word_freq = dict(zip(cv.get_feature_names(), np.asarray(bow.sum(axis=0)).ravel()))
word_counter = collections.Counter(word_freq)
word_counter_df = pd.DataFrame(word_counter.most_common(20), columns = ['word', 'freq'])

fig, ax = plt.subplots(figsize=(12, 10))
bar_freq_word = sns.barplot(x="word", y="freq", data=word_counter_df, palette="PuBuGn_d", ax=ax)
plt.show();

# %%
# draw a Word Cloud with word frequencies
wordcloud = WordCloud(width=900,
                      height=500,
                      max_words=500,
                      max_font_size=100,
                      relative_scaling=0.5,
                      colormap='Blues',
                      normalize_plurals=True).generate_from_frequencies(word_counter)

plt.figure(figsize=(17,14))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
df_model = df_eda
df_model['clean_text'] = sr_clean
df_model = df_model.drop_duplicates('clean_text')

# %%
df_model.shape
# Out:
# (49469, 12)

# %%
df_model.info
# Out:
# <bound method DataFrame.info of          count_words  count_mentions  count_hashtags  count_capital_words  \
# 557219   20           1               1               0
# 5084791  21           1               4               0
# 4330044  15           0               1               0
# 4846444  17           0               0               0
# 1338071  14           0               2               0
# 4978301  14           0               2               0
# 823173   16           1               0               1
# 5206987  14           0               2               0
# 4722239  26           0               3               1
# 3206663  17           0               9               1
# 5706962  15           0               0               0
# 790092   14           0               0               0
# 3809231  17           0               6               0
# 197554   20           0               3               3
# 2281939  13           0               8               0
# 305708   24           0               2               1
# 2459488  15           0               1               0
# 3879024  23           0               7               2
# 4625927  16           0               4               0
# 4006707  18           2               2               0
# 874156   19           0               1               1
# 4706977  14           0               1               2
# 1745137  26           1               1               1
# 4487573  18           0               2               0
# 4310308  18           0               0               0
# 567810   18           1               1               1
# 2103532  20           0               8               2
# 823678   16           0               1               0
# 3847889  22           1               2               0
# 188684   20           0               2               0
# ...      ..          ..              ..              ..
# 337171   14           1               2               0
# 750727   18           1               0               1
# 957536   21           3               4               1
# 3839417  26           1               0               0
# 5354060  23           0               3               1
# 3481862  9            0               2               0
# 1277799  25           0               1               0
# 5074626  21           0               0               0
# 4945984  14           0               2               1
# 864669   22           0               1               0
# 4249575  22           0               2               1
# 5197256  14           1               1               0
# 5310108  20           2               2               0
# 3234777  17           0               2               0
# 5311580  21           0               3               0
# 5819364  22           0               2               0
# 1754583  10           0               5               1
# 5588710  18           0               3               0
# 145109   22           2               2               0
# 427220   13           0               2               0
# 4019740  24           0               1               0
# 3919659  23           2               1               2
# 4971106  19           0               4               2
# 1569933  It is.  But not as weird as the word "Luge."  That's really weird.. :) RT @rachelloumiller #IoT is such a weird phrase... #cloudtalk
# 3016673  #Acer believes that instead of #InternetofThings, it should be #InternetofBeings. https://t.co/rsReX0HkiV
# 2119305  See how the #IoT is combatting loneliness.  Join Ericsson at the digital health catalyst at #TMFLIVE. http://t.co/LewH4f20MC
#
#         likes  retweets  \
# 557219   0     0
# 5084791  0     0
# 4330044  1     0
# 4846444  0     1
# 1338071  0     0
# 4978301  0     0
# 823173   0     0
# 5206987  0     0
# 4722239  0     0
# 3206663  0     0
# 5706962  0     0
# 790092   0     0
# 3809231  1     0
# 197554   0     1
# 2281939  2     1
# 305708   0     0
# 2459488  0     0
# 3879024  1     3
# 4625927  1     0
# 4006707  1     0
# 874156   0     0
# 4706977  0     0
# 1745137  1     3
# 4487573  0     0
# 4310308  0     0
# 567810   0     1
# 2103532  1     15
# 823678   0     0
# 3847889  0     0
# 188684   2     5
# ...     ..    ..
# 337171   0     0
# 750727   0     0
# 957536   1     0
# 3839417  0     1
# 5354060  2     0
# 3481862  0     0
# 1277799  1     0
# 5074626  0     1
# 4945984  2     0
# 864669   0     0
# 4249575  0     0
# 5197256  2     0
# 5310108  0     1
# 3234777  0     1
# 5311580  1     0
# 5819364  3     0
# 1754583  0     1
# 5588710  3     4
# 145109   0     0
# 427220   0     0
# 4019740  2     1
# 3919659  0     0
# 4971106  0     0
# 2208978  0     0
# 265380   0     0
# 2727291  5     0
# 42102    0     0
# 1569933  1     0
# 3016673  1     1
# 2119305  1     0
#
#                                                                                                         clean_text
# 557219   way internet thing creat new opportun indian busi read digitaluniversein
# 5084791  bigdata cloud iot usag increas secur concern
# 4330044  hewlett packard enterpris co launch internet thing platform iot
# 4846444  internet thing disrupt digit economi report say
# 1338071  internetofth chang world around us iot
# 4978301  cryptocurr iot work togeth forb iot infosec
# 823173   internet thing mean busi model
# 5206987  buy backbon internet thing internetofth internetofth
# 4722239  iot journey yet bigdata analyt iot josegard
# 3206663  wpgamerica iot📡 education✏ iot mm internetofth rfid bigdata cloudcomputing💭 ipad📲 textbooks📚
# 5706962  samsung launch artik cloud platform connect internet thing devices…
# 790092   internet thing could destroy welfar state
# 3809231  bigdata drive car datasci iot automobil selfdriv
# 197554   ge light announc wireless ipv street light la internet thing light arriv led light lightfair
# 2281939  sp cl mightpav dwaya toclsmoro bigdata predictiveanalyt fractal machinelearn artificialintellig iot cloud
# 305708   ibm smarter planet inti ytd encompass much big blue activ realm iot mm earn
# 2459488  wider adopt way data secur still need work iot
# 3879024  weekend best offer bigdata bootcamp dalla use code twitter get discount spark hadoop nosql iot
# 4625927  smartciti overload australia’ broadband network iot
# 4006707  interest fact “internet things” amp bigdata commun
# 874156   canadian firm slow embrac ‘internet things’ recon instrument ceo dan eisenhardt displa mastermet
# 4706977  ge hit year high buy iot
# 1745137  radio interview mark dunson amp mobeen khan discuss amp t’ iot svc connect kitchen iot
# 4487573  invok openwhisk action certain iot devic event
# 4310308  internet thing impact everyday life
# 567810   talk internet thing vendor face commun mess iot
# 2103532  publish top microservic stori bigdata iot mm api devop docker contain microservic
# 823678   internet thing devic hacker dream come true technew
# 3847889  start unleash power person market iot join us retail
# 188684   geoweb summit internet thing big data shape next phase… geospati gi
# ...                                                                      ...
# 337171   suryaray surya internet thing stalk stalk
# 750727   internet thing done wrong stifl innov anticip embrac chang
# 957536   byod mobil cloud iot need cyber secur amp
# 3839417  mean see point video babi monitor secur internet thing bad seem inconsist
# 5354060  probabl favorit thing see iot bigbelli trash can scatter throughout sf also unim…
# 3481862  sick disturb wtf iot
# 1277799  object home extend style usual go adapt live right iot none thing
# 5074626  internet thing need link close loop economi elimin wast
# 4945984  iot give rise artifici intellig iot ar
# 864669   techtalk hack net connect home internet thing secur disast
# 4249575  ieeeiot ala poor revolv bare knew ye betanew lay bare sad tale revolv iot
# 5197256  iot marathon not sprint
# 5310108  big data iot leav busi vulner cyber attack thought
# 3234777  internetofth reshap commerc wearabletech
# 5311580  iot secur threat real pose real threat cyber secur iot cybersecur datasecur
# 5819364  iot revolut not scari it’ excit essenc offer endless opportun iot pwcdigit…
# 1754583  iot explod smartcitiesunav allin secur
# 5588710  internet thing thingi designthink design tootechi
# 145109   agre mark much iot like nfc stuck discuss fix mundan old problem whilst ignor real chang
# 427220   bought iot roomba would quit within day cxmchat
# 4019740  iot secur stress bit asleep wheel
# 3919659  iot might never speak common languag ocf not make better
# 4971106  bill mccabe iot secur trend onlin world danger internetofth iot techn technew
# 2208978  semioti iot nest announc nest cam new protect smoke detector internetofth
# 265380   think inevit toilet exclud iot shame bet good stori
# 2727291  not internet thing internet custom behind thing custom df
# 42102    readwriteweb internet thing chang way work
# 1569933  not weird word luge realli weird iot weird phrase cloudtalk
# 3016673  acer believ instead internetofth internetofb
# 2119305  see iot combat loneli join ericsson digit health catalyst tmflive
#
# [49469 rows x 12 columns]>

# %%
df_model['clean_text'].replace('', np.nan, inplace=True)

# %%
df_model = df_model.dropna(axis=0, subset=['clean_text'])
df_model.head()
# Out:
#          count_words  count_mentions  count_hashtags  count_capital_words  \
# 557219   20           1               1               0
# 5084791  21           1               4               0
# 4330044  15           0               1               0
# 4846444  17           0               0               0
# 1338071  14           0               2               0
#
#          count_excl_quest_marks  count_urls  count_emojis sentiment  \
# 557219   1                       1           0             neutral
# 5084791  0                       2           0             neutral
# 4330044  0                       1           0             neutral
# 4846444  0                       1           0             neutral
# 1338071  0                       1           0             neutral
#
#                                                                                                                                           origin_text  \
# 557219   5 ways Internet of things will create new  opportunities for Indian businesses!Read here http://t.co/NiroT9Xa9I #DigitalUniverseIN @emcindia
# 5084791  As #bigdata, #cloud, and #IoT usage increases, so do #security concerns https://t.co/lXwuN7CP6s  via @ITProPortal https://t.co/8KPv2ZbcuY
# 4330044  Hewlett Packard Enterprise Co Launches an Internet of Things Platform https://t.co/qf8qKwAhFs #iot
# 4846444  The Internet of Things is about to disrupt the digital economy, report says https://t.co/RFWzNYvNY1
# 1338071  How the #InternetOfThings is changing the World around Us http://t.co/iPz10oo7hc … #IoT
#
#         likes  retweets  \
# 557219   0     0
# 5084791  0     0
# 4330044  1     0
# 4846444  0     1
# 1338071  0     0
#
#                                                                        clean_text
# 557219   way internet thing creat new opportun indian busi read digitaluniversein
# 5084791  bigdata cloud iot usag increas secur concern
# 4330044  hewlett packard enterpris co launch internet thing platform iot
# 4846444  internet thing disrupt digit economi report say
# 1338071  internetofth chang world around us iot

# %%
df_model.to_pickle('df_model.p') # save dframe to pickle

# %%
positive_tweets = pd.Series(["My room is almost 100% fully automated. Almost every device can communicate with one another. I'm so in love. I love technology. #IoT"
                      ,"I love technology! The possibilities are endless. I can’t wait to publish my first paper! 👩🏽‍💻 #Software #computerscience #computationalthinking  #iot"
                      ,"Great question! I love the #aiot example from @VolvoTrucks - predicting maintenance issues using #IoT and #AI. (link: https://www.sas.com/en_us/customers/volvo-trucks-mack-trucks.html) sas.com/en_us/customer… "])

df_counts_pos = textcount.transform(positive_tweets)
df_clean_pos = cleantext.transform(positive_tweets)
df_model_pos = df_counts_pos
df_model_pos['clean_text'] = df_clean_pos
df_model_pos.to_pickle('df_model_pos.p')

# %%
negative_tweets = pd.Series(["I really hate what people are trying to do with #IoT. It's not even practical."
                      ,"I have a love/hate with the term IoT. Too broad in many ways, but it feels good that embedded, low power and purposeful devices are making headway in great directions. #iot’s time is now."
                      ,"I do not like #Iot because i hate"
                      ,"I hate the invasiveness of #IoT and I'm worried about @google's continued overt AND covert attempts to shut down speech with which their Far Left San Francisco values disagrees. But man do I love that #HomeAlone commercial. #UTvsUGA #GoDawgs"])

df_counts_neg = textcount.transform(negative_tweets)
df_clean_neg = cleantext.transform(negative_tweets)
df_model_neg = df_counts_neg
df_model_neg['clean_text'] = df_clean_neg
df_model_neg.to_pickle('df_model_neg.p')

# %%
df_model[df_model['sentiment'] == 'negative'].sample(n=30)
# Out:
#          count_words  count_mentions  count_hashtags  count_capital_words  \
# 3032774  23           0               0               0
# 3658609  27           0               5               1
# 5184316  10           0               0               0
# 2545195  16           0               0               0
# 42001    16           0               1               0
# 3099435  22           0               2               0
# 157888   22           3               0               1
# 984358   18           0               2               0
# 4522796  13           0               0               0
# 5018196  13           0               0               0
# 3527408  24           0               0               0
# 1709839  17           1               2               0
# 3434572  24           0               7               0
# 385377   24           1               0               1
# 2490223  25           1               1               1
# 1194715  18           2               2               0
# 3043498  10           0               2               0
# 1030839  12           0               2               0
# 1368160  19           0               1               0
# 1943425  24           0               0               0
# 2776469  18           0               2               0
# 4911929  26           0               4               1
# 1189395  20           1               1               0
# 4426759  18           0               2               1
# 1938768  11           0               0               0
# 4821820  20           0               1               1
# 2178709  17           1               1               0
# 828378   22           1               3               0
# 3597540  19           1               2               0
# 1184960  27           0               1               0
#
#          count_excl_quest_marks  count_urls  count_emojis sentiment  \
# 3032774  0                       1           0             negative
# 3658609  0                       1           0             negative
# 5184316  0                       0           0             negative
# 2545195  0                       1           0             negative
# 42001    0                       1           0             negative
# 3099435  0                       2           0             negative
# 157888   0                       1           0             negative
# 984358   0                       1           0             negative
# 4522796  0                       1           0             negative
# 5018196  0                       1           0             negative
# 3527408  2                       1           0             negative
# 1709839  1                       1           0             negative
# 3434572  0                       1           0             negative
# 1189395  Security Experts Believe the Internet of Things Will Be Used To Kill Someone @slashdot http://t.co/9G2SiedwIp #TheFutureIsScary :S
# 4426759  More and more #IoT is synonym of #WTF: Here comes the connected fly trousers! https://t.co/DC90bkQcmP
# 1938768  Internet of Things devices is really an awkward term. Too long.
# 4821820  Atos_IDA: Lack of #IoT leadership is hurting agencies I fedscoop RT evankirstel  https://t.co/L1WDkRGkfp https://t.co/4FEWCWTtJp
# 2178709  5 Reasons Why My #IoT Startup Failed by @YashPKotak. Interesting article worth reading! http://t.co/kJsK2S9cwF
# 828378   Tech geeks, don't miss this @Accion_Global post on how the #InternetOfThings can help the poor: http://t.co/BFaS6N4VQ3 #socbiz #socent
# 3597540  Nokia's IoT security tool works with gear from many vendors https://t.co/6cDmWGIydn via @computerworld #IoT #IoTSecurity
# 1184960  A1. IoT and Mobile impact drive-thru food retail... my pref is a skinny ginger-bread latte..it's prep starts when I'm in line  #ioTchat
#
#         likes  retweets  \
# 3032774  0     0
# 3658609  4     0
# 5184316  0     0
# 2545195  0     0
# 42001    0     0
# 3099435  0     0
# 157888   0     0
# 984358   1     0
# 4522796  0     0
# 5018196  0     0
# 3527408  2     2
# 1709839  0     4
# 3434572  1     0
# 385377   0     0
# 2490223  0     0
# 1194715  3     2
# 3043498  0     0
# 1030839  6     9
# 1368160  0     0
# 1943425  4     0
# 2776469  3     4
# 4911929  0     0
# 1189395  0     0
# 4426759  3     3
# 1938768  0     0
# 4821820  0     0
# 2178709  1     0
# 828378   1     5
# 3597540  1     0
# 1184960  0     0
#
#                                                                                             clean_text
# 3032774  home offic increasingli surround internet thing devic not built secur mind tra…
# 3658609  exact reason iot doesn’t need ipv prove one post ipv ipv nat
# 5184316  wish knew internet thing
# 2545195  current read patrick watson internet thing take wrong turn
# 42001    twitapp internet thing chang way work
# 3099435  iot not threat opportun chang data world
# 157888   internet thing arriv massiv secur issu amp
# 984358   gadget internet thing must program die softwar dev
# 4522796  internet thing confus barron
# 5018196  internet thing need differ encrypt nextgov
# 3527408  argh saw problem internet thing secur bad there’ search engin sleep kid
# 1709839  bigdata plu iot big enterpris big deal
# 3434572  iot no alarm wake balanc ruggi kickstart tech iot wearabl
# 385377   thing need exist ce connect crockpot show internet thing exist
# 2490223  bad msm stop internet thing citizen connect see video full defundpp
# 1194715  internetofth face secur headach mass adopt explain
# 3043498  iot predict wrong
# 1030839  industri iot not singl technolog iotwf
# 1368160  newsworld netappvoic hate internet thing love internet thing
# 1943425  internet thing becom feasibl day back world power cheap comput
# 2776469  marriag market amp iot realli lie
# 4911929  iot data manag issu worri uk consum tech vendor iot wearabl mm big…
# 1189395  secur expert believ internet thing use kill someon thefutureisscari
# 4426759  iot synonym wtf come connect fli trouser
# 1938768  internet thing devic realli awkward term long
# 4821820  atosida lack iot leadership hurt agenc fedscoop evankirstel
# 2178709  reason iot startup fail interest articl worth read
# 828378   tech geek miss post internetofth help poor socbiz socent
# 3597540  nokia iot secur tool work gear mani vendor iot iotsecur
# 1184960  iot mobil impact drive thru food retail pref skinni ginger bread latt prep start line iotchat
