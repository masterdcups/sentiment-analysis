# %%
# Loading xml dataset --- OK
# PS : Go to affectivetext_test.xml and replace & by &amp;

from xml.dom import minidom
import pandas as pd

def _SemEval2007_Path2String(X_path, y_path):
    #print('hello before minidom parse')
    xmldoc = minidom.parse(X_path)
    itemlist = xmldoc.getElementsByTagName('instance')

    file = open(y_path)
    lines = file.read().split('\n')
    #print(len(lines))
    lines = lines[0:-1]

    assert len(itemlist) == len(lines), 'data size not uniform'

    X = {}
    y = {}

    for item in itemlist:
        id = int(item.attributes['id'].value)
        X[id] = item.firstChild.nodeValue

    for line in lines:
        items = line.split(' ')
        id = int(items[0])
        y[id] = []
        for i in range(1, len(items)):
            y[id].append(float(items[i]))

    return X, y

def Load_SemEval2007Data():
    DATA_X_PATH1 = "../data/AffectiveText.test/affectivetext_test.xml"
    DATA_Y_PATH1 = "../data/AffectiveText.test/affectivetext_test.emotions.gold"

    DATA_X_PATH2 = "../data/AffectiveText.trial/affectivetext_trial.xml"
    DATA_Y_PATH2 = "../data/AffectiveText.trial/affectivetext_trial.emotions.gold"

    X1, y1 = _SemEval2007_Path2String(DATA_X_PATH1, DATA_Y_PATH1)
    X2, y2 = _SemEval2007_Path2String(DATA_X_PATH2, DATA_Y_PATH2)
    # y.update(y2)
    # print(X1)
    # print(y1)

    df = pd.DataFrame([X1, y1])

    emotions = ["anger", "disgust", "fear", "joy", "sadness", "surprise"]
    for column in df:  # retenir le score maximal
        df[column][1] = emotions[df[column][1].index(max(df[column][1]))]
        # print(df[column])

    return df.T

# %%
# Loading arff dataset
import arff
import pandas as pd

def loadDEFT2015():
    df = pd.DataFrame(columns=['text', 'emotion'])
    data = list(arff.load('Corpus.de.tweets.en.français/DEFT2015-arff/Train2.2.arff'))

    for i in range(len(data)):
        item = data[i]
        df.loc[i] = [item[0], item[1]]

    return df

# %%
# loading txt dataset --- OK 

def loadEmotionTweet(train_path, dev_path):
    train = pd.read_csv(train_path,sep='\t',index_col=[0])
    dev = pd.read_csv(dev_path,sep='\t',index_col=[0])
    train = pd.concat([train,dev])
    train = train.sample(frac=1)  # just shuffle
    #train['Tweet'] = train['Tweet'].apply(lambda x:x.lower())

    return train

# %%
df = loadEmotionTweet("../data/EmotionTweet/2018-E-c-En-train.txt", "../data/EmotionTweet/2018-E-c-En-dev.txt")
df.to_pickle('data/final/NotIot_EN_tweets.p')

# %%
df2 = Load_SemEval2007Data()
df2.to_pickle('data/final/NotIot_EN_News.p')
# Out:
#                                                       0         1
# 500   Test to predict breast cancer relapse is approved       joy
# 501   Two Hussein allies are hanged, Iraqi official ...   sadness
# 502                          Sights and sounds from CES       joy
# 503                  Schuey sees Ferrari unveil new car       joy
# 504   Closings and cancellations top advice on flu o...      fear
# 505                 Trucks swallowed in subway collapse   sadness
# 506    Sarkozy letter surprises French cartoons hearing  surprise
# 507   Building a memorial to a son, one child at a time   sadness
# 508   Lawmaker seeks iPod ban in crosswalks in New York  surprise
# 509                Diabetic waits months for eyeglasses   sadness
# 510   Sudan tells United Nations envoy to leave in 7...  surprise
# 511              5000 years on but couple still hugging  surprise
# 512          Defense to challenge Russert's credibility  surprise
# 513            Ozzy, a Hero for the hard-rocking masses       joy
# 514                              CIA leak trial summary  surprise
# 515                        Dance movie takes over No. 1       joy
# 516                   Asian nations urge Myanmar reform  surprise
# 517        After Iraq trip, Clinton proposes war limits       joy
# 518                   7 dead in apartment building fire   sadness
# 519            Male sweat boosts women's hormone levels  surprise
# 520                  Carphone Warehouse's mixed signals  surprise
# 521          Democrats plot Bush troop increase censure  surprise
# 522                   Cisco sues Apple over iPhone name     anger
# 523               BB star Jackson denies Goody comments   disgust
# 524                  Inter Milan set Serie A win record       joy
# 525                     US Airways boosts bid for Delta  surprise
# 526                      Press sees hope in Mecca talks       joy
# 527                Bears fan loses bet and changes name  surprise
# 528         Global National\tMajor child porn ring bust   disgust
# 529              'Human hair' clue in hunt for airliner  surprise
# ...                                                 ...       ...
# 1470               Frantic 911 call in Ryan O'Neal case  surprise
# 1471                 Durant's success trumps the Gators       joy
# 1472           Scientist snoops in astronauts' journals   disgust
# 1473                YouTube founders split $650M payout       joy
# 1474               African nation hopes Whoopi can help       joy
# 1475                   United hang on to six-point lead       joy
# 1476                 Lawyer seizes Smith's Bahamas home   sadness
# 1477             Was Prince's super show too revealing?  surprise
# 1478                 Clijsters looks for a long goodbye   sadness
# 1479               Snow's too deep even for snowmobiles  surprise
# 1480              Study: Female seals picky about mates  surprise
# 1481  ROUNDUP: Protests erupt despite "state of sieg...     anger
# 1482            Study: More kids exposed to online porn   disgust
# 1483                   Beyonce new SI bikini cover girl       joy
# 1484    Marijuana helps ease HIV nerve pain, study says  surprise
# 1485                 Serena misses Bangalore tournament   sadness
# 1486        Dryer blamed for fire killing 39 cats, dogs   sadness
# 1487                  Roddick, Murray score in San Jose       joy
# 1488                    Apple trademark dispute settled       joy
# 1489                 U.S. online love brokers eye China   sadness
# 1490               U.S. diverts troops to fight Taliban     anger
# 1491         'House of Cards' actor Ian Richardson dead   sadness
# 1492                 Taliban leader killed in airstrike   sadness
# 1493         Escape to Prague without the summer hordes       joy
# 1494                  Kathmandu: First snow in 63 years  surprise
# 1495                        Nasdaq fails in bid for LSE   sadness
# 1496                      Ex-pastor gets death sentence   sadness
# 1497        Baby born on turnpike after dad misses exit  surprise
# 1498                   Study links chimps and 'hammers'  surprise
# 1499                 UN-Google Earth map climate change       joy
#
# [1000 rows x 2 columns]

# %%
import pandas as pd
dff = pd.read_pickle("loadingScripts/loaded_datasets/Test2.2.pkl")
dff.to_pickle('data/final/NotIot_FR_tweets_test.p')
# Out:
#                                                    text            emotion
# 0     La technologie clé contre le changement climat...       VALORISATION
# 1     @JMoncomble Probablement une histoire de dével...     DEVALORISATION
# 2     C\'est moi où l\'énergie naturelle est plus fo...       VALORISATION
# 3     Nous cherchons à changer l’économie mondiale e...       VALORISATION
# 4     @RemiMathis Les achats par l\'Internet sont éc...       VALORISATION
# 5     Energie durable : Sgolne Royal salue l\'engage...       VALORISATION
# 6     Actus énergie : Alerte navires VALIANT - 470 S...               PEUR
# 7     C’est maintenant à votre tour d’apporter votre...       VALORISATION
# 8     #ecologie Quid sur les meilleurs produits écol...       VALORISATION
# 9     L\'énergie nucléaire apparaît comme l\'un des ...       VALORISATION
# 10    #Education: Jacques Tapin ex-élu municipal nio...       VALORISATION
# 11    Bienvenue à Elsa Jeannes @ElsaJeannes étudiant...            PLAISIR
# 12    #mer #sécurité #détresse # météo La radio VHF ...       VALORISATION
# 13    Ségolène Royal @RoyalSegolene · 13 min Je vien...       VALORISATION
# 14    La Cour des comptes européenne critique la ges...          DESACCORD
# 15    Artea une foncière entièrement dédiée aux imme...       VALORISATION
# 16    Les clusters HPC sous Nvidia champions de l’ef...       VALORISATION
# 17    RT @jubouissou L\'Inde crée un fonds d\'adapta...       VALORISATION
# 18    La technologie clé contre le changement climat...          DESACCORD
# 19    J\'ai froid... Il vient quand le soleil là ? C...             MEPRIS
# 20    Achevez-moi toussuite @Amandiine: Le changemen...             COLERE
# 21    @LaMortLaVraie Ce n\'est pas très développemen...             COLERE
# 22    #immobilier Solar Décathlon : l\'innovation ra...       VALORISATION
# 23    La technologie clé contre le changement climat...       VALORISATION
# 24    Eoliennes en baie de Saint-Brieuc. Fondation :...       SATISFACTION
# 25    @futurasciences: Les appareils connectés en mo...     DEVALORISATION
# 26    La technologie clé contre le changement climat...       VALORISATION
# 27    Admis en Master 2 Droit et Gestion de l\'#Envi...       VALORISATION
# 28    Accord des partenaires sur les structures jack...             ACCORD
# 29    Attention Rappel des navires de Marque VALIANT...               PEUR
# ...                                                 ...                ...
# 1331  Je n\'ai vu AUCUN sujet sur l\'environnement l...     DEVALORISATION
# 1332  Le réchauffement climatique n’a pas que des in...     DEVALORISATION
# 1333  #biodiversité La France durcit la lutte contre...          DESACCORD
# 1334  @RoyalSegolene complice du déboisement de la f...     DEVALORISATION
# 1335  #GCO : les écologistes strasbourgeois sont stu...  SURPRISE_POSITIVE
# 1336  #biodiversité Les pêcheurs artisanaux de plus ...               PEUR
# 1337  #Strasbourg #GCO : les écologistes strasbourge...  SURPRISE_NEGATIVE
# 1338  #Bargy. Polémique sur l’#abattage massif de #b...     DEVALORISATION
# 1339  @IMAD_A @Cabouzaid je ne sais pas je ne suis p...     DEVALORISATION
# 1340  Les Strasbourgeois bientôt chauffés grâce à le...     DEVALORISATION
# 1341  Vous voulez les infos? Des morts la crise écon...     DEVALORISATION
# 1342  Nous sommes soulagés chez les écologistes de l...         APAISEMENT
# 1343  Non à la répression contre la ZAD du #Testet !...          DESACCORD
# 1344  @paolomrecha lol ça existe des foyers dotés d\...     DEVALORISATION
# 1345  dans ma classe j\'ai lgenre de mec ou tu lui p...          DEPLAISIR
# 1346  1 300 espèces menacées : comment les oiseaux s...     DEVALORISATION
# 1347  Salut Bonjour! - Roy Dupuis et Samian : coup d...             COLERE
# 1348  Cuba: Mesures contre les effets du changement ...          DESACCORD
# 1349  La lutte contre la mosaïque du manioc aux Como...          DESACCORD
# 1350  1 300 espèces menacées : comment les oiseaux s...     DEVALORISATION
# 1351  L’exportation de l’énergie éolienne une source...          DEPLAISIR
# 1352  L’exportation de l’énergie éolienne une source...          DEPLAISIR
# 1353  Un réseau de journalistes pour lutter contre l...          DESACCORD
# 1354  Polémique autour de l’abattage massif de bouqu...          DESACCORD
# 1355  #GCO : les écologistes strasbourgeois sont stu...  SURPRISE_NEGATIVE
# 1356  Info: Éoliennes - Le résultat de l’enquête pub...     DEVALORISATION
# 1357  Réchauffement : l’ONU prédit un véritable «enf...     DEVALORISATION
# 1358  Les espèces disparaissent 1.000 fois plus depu...               PEUR
# 1359  #Biodiversité #Gard : Des Lézards ocellés détr...     DEVALORISATION
# 1360  Royal: le président n\'aime pas les pauvres? c...             COLERE
#
# [1361 rows x 2 columns]

# %%
csv_file = "data/french_iot_tweets.csv"
df = pd.read_csv(csv_file, header=None)
df = df.iloc[:,[0,6,7]]
df.rename(index=str, columns={6: "a", 7: "c"})
df
# Out:
#                        0                                                  6  \
# 0             6744377784  @barby_ Tiens, le Nabaztag n'était que la part...
# 1            10875388737  RT @PierreMetivier Revue du livre "La métamorp...
# 2             6531009271  TagMyLagoon - C'est Venise, c'est du sans -con...
# 3             9987955641  @dzakyem oui de mon point de vue amateur.  qui...
# 4            19288834468  Deloitte Review article Asset Intelligence #io...
# 5            11754961072  Waiting for @xtof_fr & @billcpu for #IOT discu...
# 6            13849600171  RT @PierreMetivier: Le réfrigérateur intellige...
# 7             8205056492  L'après Nabaztag http://bit.ly/7sqrEr ! #inter...
# 8            21621796224  5 milliards d'objets connectés ! - http://j.mp...
# 9            11763846454  @dumeny impatient de poursuivre ce brainstorm ...
# 10            5026166781  New chance for the #IoT rabbit for €350: RT @m...
# 11           11315261485  #internetdesobjets La croissance reste forte, ...
# 12           11993764100  @lentremetteur oui dès qu'on aura trouvé un be...
# 13            5795149352  )i( interstices - À propos de l'Internet des o...
# 14           23167190198  Débat sur le mobile  en direct live  sur Europ...
# 15           21462216649  Infinite Power Solutions Raises $20.0M http://...
# 16            5795633523  RT @mathemagie )i( interstices - À propos de l...
# 17           18484609099    Soil moisture monitor http://bit.ly/amLRFM #IoT
# 18           11042561458  Livraison 'internet des objets quels enjeux po...
# 19            8984885306  Promo #microformats : ch. imprimeur français d...
# 20           20297558415  Chez @ChristianFaure : "Le cloud computing et ...
# 21           22279329764  RT @rww 10 Vidéos présentant l'Internet des Ob...
# 22           12449454264  #iot "L'internet des choses" expliqué par @tim...
# 23            8897090042  @Mariegaraud oui merci ma belle. serai ravi de...
# 24           12337259176  @egadenne Ca a l'air d'être un excellent conce...
# 25            8991794269  RT @xtof_fr - Promo #microformats : ch. imprim...
# 26            8243782705  Les objets, acteurs du web de demain ? http://...
# 27           20484122877   WSN Competitive Matrix http://bit.ly/c2Yfoz #IoT
# 28           18617693244  Orange confirme son avance sur le marché des s...
# 29            7939750495  R.Haladjian pose la bonne question #IOT #petit...
# ...                  ...                                                ...
# 1557  999295484996083713  Protec Card intègre le programme @amazonlaunch...
# 1558  999299973882810369  @VINCIEnergies investit dans la start-up @Gree...
# 1559  999312001255043072  Un potentiel marché de 3 000 milliards de $ po...
# 1560  999303313500835840  Projet Internet Food &amp; #Farm: A la recherc...
# 1561  999291158873460736  Les obstacles à l'adoption de la réalité augme...
# 1562  999289699851276289  Le temps passé chaque jour sur Internet via un...
# 1563  999315760743899137  Retrouvez l'Acsel sur le stand du @GroupeLaPos...
# 1564  999311493152768003  Les objets connectés #IoT de #santé sont de pl...
# 1565  999332889694269440  Kuzzle et Qwant présentent un partenariat dans...
# 1566  999311456297504769  Internet des objets (#IoT) : l’éthique, clé d’...
# 1567  999321297174827008  SES-imagotag : un objectif de chiffre d'affair...
# 1568  999319455141384192  #BIM et objets connectés : le forum BIMOC se t...
# 1569  999292932380340225  Virginia Rometty, PDG d’IBM : « Nous allons cr...
# 1570  999304164357345281  “En 2020 Près de 50 milliars d'#IoT seront en ...
# 1571  999298380479258625  Et si vous vous formiez aux objets connectés ?...
# 1572  999301268349865984  Numerama : Tech for Good : IBM promet 1 800 no...
# 1573  999296026656870400  Automatisation, Machine Learning et IA : l'adm...
# 1574  999332193460785152  Kuzzle et Qwant présentent un partenariat dans...
# 1575  999318774766587904  SES-imagotag présente son plan stratégique " V...
# 1576  999324986916696065  SES-imagotag présente son plan stratégique « V...
# 1577  999322145766375425  La stratégie de Sanofi pour se développer dans...
# 1578  999324126270640128  [#Cybersécurité] Face à l’explosion de nouvell...
# 1579  999315007954399232  La #startup @Etmoiconnect #Iot remarquée au #c...
# 1580  999326895706697729  La sélection de #BONSPLANS #DOMOTIQUE, #IOT, #...
# 1581  999325838247124992  La sélection de #BONSPLANS #DOMOTIQUE, #IOT, #...
# 1582  999302689119973376  #IoT : l’éthique, clé d’une souveraineté europ...
# 1583  999298319116627973  Faut-il se méfier des équipementiers chinois d...
# 1584  999304575638212609  Plus que quelques heures avant le début de #Vi...
# 1585  999306457320325120  #IoT et #Blockchain deux technologies aux serv...
# 1586  999300132393947136  @UDA_annonceurs sera présent à @VivaTech. Vene...
#
#                                                    7
# 0                                  internetdesobjets
# 1                                  internetdesobjets
# 2                                        autoID  iot
# 3                                         spime  iot
# 4                                    iot  innovation
# 5                                                IOT
# 6                                                iot
# 7                                  internetdesobjets
# 8                       Ido  internetdesobjets  web3
# 9                                                iot
# 10                                               IoT
# 11                                 internetdesobjets
# 12                                               iot
# 13                          audio  internetdesobjets
# 14                                               iot
# 15                                               IoT
# 16                          audio  internetdesobjets
# 17                                               IoT
# 18                                               iot
# 19                      microformats  3Dprinter  iot
# 20                          cloud  internetdesobjets
# 21                                  sanscontact  iot
# 22                                               iot
# 23                                 internetdesobjets
# 24                     stickybits  internetdesobjets
# 25                      microformats  3Dprinter  iot
# 26         internetdesobjets  internetofthings  web3
# 27                                               IoT
# 28                                               IoT
# 29                                  IOT  petitdejweb
# ...                                              ...
# 1557                                         startup
# 1558                                             IoT
# 1559                                             NaN
# 1560                                            Farm
# 1561                                             iot
# 1562                                          mobile
# 1563                                    VivaTech2018
# 1564                                      IoT  santé
# 1565                                             NaN
# 1566                                             IoT
# 1567                                             iot
# 1568                                        BIM  IoT
# 1569                                              IA
# 1570                                             IoT
# 1571                                             IoT
# 1572                            Business  Blockchain
# 1573                                             NaN
# 1574                                             IoT
# 1575                                             NaN
# 1576                                             iot
# 1577                                             IoT
# 1578    Cybersécurité  IOT  IntelligenceArtificielle
# 1579                          startup  Iot  concours
# 1580  BONSPLANS  DOMOTIQUE  IOT  DRONE  IMPRESSION3D
# 1581  BONSPLANS  DOMOTIQUE  IOT  DRONE  IMPRESSION3D
# 1582                            IoT  ethique  ethics
# 1583          smartphone  Xiaomi  Oppo  Vivo  France
# 1584                                        Vivatech
# 1585         IoT  Blockchain  cybersecurite  BigData
# 1586                                             NaN
#
# [1587 rows x 3 columns]

# %%
df.to_pickle('data/final/Iot_FR_tweets.p')

# %%
csv_file = "../code_news/news_en.csv"
df = pd.read_csv(csv_file, header=None, encoding='utf-8')
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x85 in position 49: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-52-23066b47eb8e> in <module>
#       1 csv_file = "../code_news/news_en.csv"
# ----> 2 df = pd.read_csv(csv_file, header=None, encoding='utf-8')
#       3 df
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     433
#     434     try:
# --> 435         data = parser.read(nrows)
#     436     finally:
#     437         parser.close()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1137     def read(self, nrows=None):
#    1138         nrows = _validate_integer('nrows', nrows)
# -> 1139         ret = self._engine.read(nrows)
#    1140
#    1141         # May alter columns / col_dict
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1993     def read(self, nrows=None):
#    1994         try:
# -> 1995             data = self._reader.read(nrows)
#    1996         except StopIteration:
#    1997             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x85 in position 49: invalid start byte

# %%
# !jupyter nbconvert --to script loading_data.ipynb
# Out:
# [NbConvertApp] Converting notebook loading_data.ipynb to script
# [NbConvertApp] Writing 3144 bytes to loading_data.py
